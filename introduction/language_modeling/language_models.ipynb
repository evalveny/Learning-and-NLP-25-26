# %% [markdown]
# # Language Modeling with NLTK

# %% [markdown]
# ## Selecting a corpus
#
# First we need to select a corpus that will be used to train the language model. We will select *Alice's Adventures in Wonderland*, a novel by Lewis Carroll, that can be found in the Gutenberg Corpus​​ NLTK.

# %%
from nltk.corpus import gutenberg

# Access the text of "Alice's Adventures in Wonderland"
alice_text = gutenberg.raw("carroll-alice.txt")
# Print the first 500 characters as a sample
print(alice_text[:500])
# Out:
# [Alice's Adventures in Wonderland by Lewis Carroll 1865]
#
# CHAPTER I. Down the Rabbit-Hole
#
# Alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to do: once or twice she had peeped into the
# book her sister was reading, but it had no pictures or conversations in
# it, 'and what is the use of a book,' thought Alice 'without pictures or
# conversation?'
#
# So she was considering in her own mind (as well as she could, for the
# hot day made her feel very sleepy an

# %% [markdown]
# ## Pre-processing the corpus

# %% [markdown]
# First, we convert the text to lowercase to normalize words

# %%
# Convert to lowercase (word normalization)
alice_text = alice_text.lower()
# Print the first 500 characters
print(alice_text[:500])
# Out:
# [alice's adventures in wonderland by lewis carroll 1865]
#
# chapter i. down the rabbit-hole
#
# alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to do: once or twice she had peeped into the
# book her sister was reading, but it had no pictures or conversations in
# it, 'and what is the use of a book,' thought alice 'without pictures or
# conversation?'
#
# so she was considering in her own mind (as well as she could, for the
# hot day made her feel very sleepy an

# %% [markdown]
# Segment the text into sentences

# %%
from nltk import sent_tokenize

sentences = sent_tokenize(alice_text)

# Print the first 10 sentences
for sent in sentences[:10]:
    print(sent)
    print("_________________")
# Out:
# [alice's adventures in wonderland by lewis carroll 1865]
#
# chapter i. down the rabbit-hole
#
# alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to do: once or twice she had peeped into the
# book her sister was reading, but it had no pictures or conversations in
# it, 'and what is the use of a book,' thought alice 'without pictures or
# conversation?'
# _________________
# so she was considering in her own mind (as well as she could, for the
# hot day made her feel very sleepy and stupid), whether the pleasure
# of making a daisy-chain would be worth the trouble of getting up and
# picking the daisies, when suddenly a white rabbit with pink eyes ran
# close by her.
# _________________
# there was nothing so very remarkable in that; nor did alice think it so
# very much out of the way to hear the rabbit say to itself, 'oh dear!
# _________________
# oh dear!
# _________________
# i shall be late!'
# _________________
# (when she thought it over afterwards, it
# occurred to her that she ought to have wondered at this, but at the time
# it all seemed quite natural); but when the rabbit actually took a watch
# out of its waistcoat-pocket, and looked at it, and then hurried on,
# alice started to her feet, for it flashed across her mind that she had
# never before seen a rabbit with either a waistcoat-pocket, or a watch
# to take out of it, and burning with curiosity, she ran across the field
# after it, and fortunately was just in time to see it pop down a large
# rabbit-hole under the hedge.
# _________________
# in another moment down went alice after it, never once considering how
# in the world she was to get out again.
# _________________
# the rabbit-hole went straight on like a tunnel for some way, and then
# dipped suddenly down, so suddenly that alice had not a moment to think
# about stopping herself before she found herself falling down a very deep
# well.
# _________________
# either the well was very deep, or she fell very slowly, for she had
# plenty of time as she went down to look about her and to wonder what was
# going to happen next.
# _________________
# first, she tried to look down and make out what
# she was coming to, but it was too dark to see anything; then she
# looked at the sides of the well, and noticed that they were filled with
# cupboards and book-shelves; here and there she saw maps and pictures
# hung upon pegs.
# _________________

# %% [markdown]
# Tokenize sentences into tokens. In this case, we will utilize the TweetTokenizer.

# %%
from nltk.tokenize import TweetTokenizer

tweet_tokenizer = TweetTokenizer()

sentences_tokenized = []

for sent in sentences:
    sent_tok = tweet_tokenizer.tokenize(sent)
    sentences_tokenized.append(sent_tok)

# Print the first 10 tokenized sentences
for sent_tok in sentences_tokenized[:10]:
    print(sent_tok)
    print("_________________")
# Out:
# ['[', "alice's", 'adventures', 'in', 'wonderland', 'by', 'lewis', 'carroll', '1865', ']', 'chapter', 'i', '.', 'down', 'the', 'rabbit-hole', 'alice', 'was', 'beginning', 'to', 'get', 'very', 'tired', 'of', 'sitting', 'by', 'her', 'sister', 'on', 'the', 'bank', ',', 'and', 'of', 'having', 'nothing', 'to', 'do:', 'once', 'or', 'twice', 'she', 'had', 'peeped', 'into', 'the', 'book', 'her', 'sister', 'was', 'reading', ',', 'but', 'it', 'had', 'no', 'pictures', 'or', 'conversations', 'in', 'it', ',', "'", 'and', 'what', 'is', 'the', 'use', 'of', 'a', 'book', ',', "'", 'thought', 'alice', "'", 'without', 'pictures', 'or', 'conversation', '?', "'"]
# _________________
# ['so', 'she', 'was', 'considering', 'in', 'her', 'own', 'mind', '(', 'as', 'well', 'as', 'she', 'could', ',', 'for', 'the', 'hot', 'day', 'made', 'her', 'feel', 'very', 'sleepy', 'and', 'stupid', ')', ',', 'whether', 'the', 'pleasure', 'of', 'making', 'a', 'daisy-chain', 'would', 'be', 'worth', 'the', 'trouble', 'of', 'getting', 'up', 'and', 'picking', 'the', 'daisies', ',', 'when', 'suddenly', 'a', 'white', 'rabbit', 'with', 'pink', 'eyes', 'ran', 'close', 'by', 'her', '.']
# _________________
# ['there', 'was', 'nothing', 'so', 'very', 'remarkable', 'in', 'that', ';', 'nor', 'did', 'alice', 'think', 'it', 'so', 'very', 'much', 'out', 'of', 'the', 'way', 'to', 'hear', 'the', 'rabbit', 'say', 'to', 'itself', ',', "'", 'oh', 'dear', '!']
# _________________
# ['oh', 'dear', '!']
# _________________
# ['i', 'shall', 'be', 'late', '!', "'"]
# _________________
# ['(', 'when', 'she', 'thought', 'it', 'over', 'afterwards', ',', 'it', 'occurred', 'to', 'her', 'that', 'she', 'ought', 'to', 'have', 'wondered', 'at', 'this', ',', 'but', 'at', 'the', 'time', 'it', 'all', 'seemed', 'quite', 'natural', ');', 'but', 'when', 'the', 'rabbit', 'actually', 'took', 'a', 'watch', 'out', 'of', 'its', 'waistcoat-pocket', ',', 'and', 'looked', 'at', 'it', ',', 'and', 'then', 'hurried', 'on', ',', 'alice', 'started', 'to', 'her', 'feet', ',', 'for', 'it', 'flashed', 'across', 'her', 'mind', 'that', 'she', 'had', 'never', 'before', 'seen', 'a', 'rabbit', 'with', 'either', 'a', 'waistcoat-pocket', ',', 'or', 'a', 'watch', 'to', 'take', 'out', 'of', 'it', ',', 'and', 'burning', 'with', 'curiosity', ',', 'she', 'ran', 'across', 'the', 'field', 'after', 'it', ',', 'and', 'fortunately', 'was', 'just', 'in', 'time', 'to', 'see', 'it', 'pop', 'down', 'a', 'large', 'rabbit-hole', 'under', 'the', 'hedge', '.']
# _________________
# ['in', 'another', 'moment', 'down', 'went', 'alice', 'after', 'it', ',', 'never', 'once', 'considering', 'how', 'in', 'the', 'world', 'she', 'was', 'to', 'get', 'out', 'again', '.']
# _________________
# ['the', 'rabbit-hole', 'went', 'straight', 'on', 'like', 'a', 'tunnel', 'for', 'some', 'way', ',', 'and', 'then', 'dipped', 'suddenly', 'down', ',', 'so', 'suddenly', 'that', 'alice', 'had', 'not', 'a', 'moment', 'to', 'think', 'about', 'stopping', 'herself', 'before', 'she', 'found', 'herself', 'falling', 'down', 'a', 'very', 'deep', 'well', '.']
# _________________
# ['either', 'the', 'well', 'was', 'very', 'deep', ',', 'or', 'she', 'fell', 'very', 'slowly', ',', 'for', 'she', 'had', 'plenty', 'of', 'time', 'as', 'she', 'went', 'down', 'to', 'look', 'about', 'her', 'and', 'to', 'wonder', 'what', 'was', 'going', 'to', 'happen', 'next', '.']
# _________________
# ['first', ',', 'she', 'tried', 'to', 'look', 'down', 'and', 'make', 'out', 'what', 'she', 'was', 'coming', 'to', ',', 'but', 'it', 'was', 'too', 'dark', 'to', 'see', 'anything', ';', 'then', 'she', 'looked', 'at', 'the', 'sides', 'of', 'the', 'well', ',', 'and', 'noticed', 'that', 'they', 'were', 'filled', 'with', 'cupboards', 'and', 'book-shelves', ';', 'here', 'and', 'there', 'she', 'saw', 'maps', 'and', 'pictures', 'hung', 'upon', 'pegs', '.']
# _________________

# %% [markdown]
# ## Training the Language Model
#
# See complete documentation in https://www.nltk.org/api/nltk.lm.html

# %% [markdown]
# #### Compute n-grams in the training text
#
# First we need to get all the n-grams from the training text and the vocabulary of valid words. We can do that using the function `padded_everygram_pipeline`
#
# Taking as parameters the order of n-grams and the list of tokenized sentences, returns the list of n-grams and the list of words in the vocabulary. It adds special tokens for start and end of sentence (`<s>` and `<\s>`)

# %%
from nltk.lm.preprocessing import padded_everygram_pipeline

# Order of n-grams = 2. It will use unigrams and bigrams.
n = 2
train, vocab = padded_everygram_pipeline(n, sentences_tokenized)

vocab_list = list(vocab)

# Prints the n-grams for training
print ("Training n-grams")
for sentence in train:
    for n_gram in sentence:
        print(n_gram)

# Prnts the vocabulary list and its length
print("Vocabulary words: ", vocab_list)
print ("Vocabulary length: ", len(vocab_list))
# Out:
# Training n-grams
# ('<s>',)
# ('<s>', '[')
# ('[',)
# ('[', "alice's")
# ("alice's",)
# ("alice's", 'adventures')
# ('adventures',)
# ('adventures', 'in')
# ('in',)
# ('in', 'wonderland')
# ('wonderland',)
# ('wonderland', 'by')
# ('by',)
# ('by', 'lewis')
# ('lewis',)
# ('lewis', 'carroll')
# ('carroll',)
# ('carroll', '1865')
# ('1865',)
# ('1865', ']')
# (']',)
# (']', 'chapter')
# ('chapter',)
# ('chapter', 'i')
# ('i',)
# ('i', '.')
# ('.',)
# ('.', 'down')
# ('down',)
# ('down', 'the')
# ('the',)
# ('the', 'rabbit-hole')
# ('rabbit-hole',)
# ('rabbit-hole', 'alice')
# ('alice',)
# ('alice', 'was')
# ('was',)
# ('was', 'beginning')
# ('beginning',)
# ('beginning', 'to')
# ('to',)
# ('to', 'get')
# ('get',)
# ('get', 'very')
# ('very',)
# ('very', 'tired')
# ('tired',)
# ('tired', 'of')
# ('of',)
# ('of', 'sitting')
# ('sitting',)
# ('sitting', 'by')
# ('by',)
# ('by', 'her')
# ('her',)
# ('her', 'sister')
# ('sister',)
# ('sister', 'on')
# ('on',)
# ('on', 'the')
# ('the',)
# ('the', 'bank')
# ('bank',)
# ('bank', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'of')
# ('of',)
# ('of', 'having')
# ('having',)
# ('having', 'nothing')
# ('nothing',)
# ('nothing', 'to')
# ('to',)
# ('to', 'do:')
# ('do:',)
# ('do:', 'once')
# ('once',)
# ('once', 'or')
# ('or',)
# ('or', 'twice')
# ('twice',)
# ('twice', 'she')
# ('she',)
# ('she', 'had')
# ('had',)
# ('had', 'peeped')
# ('peeped',)
# ('peeped', 'into')
# ('into',)
# ('into', 'the')
# ('the',)
# ('the', 'book')
# ('book',)
# ('book', 'her')
# ('her',)
# ('her', 'sister')
# ('sister',)
# ('sister', 'was')
# ('was',)
# ('was', 'reading')
# ('reading',)
# ('reading', ',')
# (',',)
# (',', 'but')
# ('but',)
# ('but', 'it')
# ('it',)
# ('it', 'had')
# ('had',)
# ('had', 'no')
# ('no',)
# ('no', 'pictures')
# ('pictures',)
# ('pictures', 'or')
# ('or',)
# ('or', 'conversations')
# ('conversations',)
# ('conversations', 'in')
# ('in',)
# ('in', 'it')
# ('it',)
# ('it', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'and')
# ('and',)
# ('and', 'what')
# ('what',)
# ('what', 'is')
# ('is',)
# ('is', 'the')
# ('the',)
# ('the', 'use')
# ('use',)
# ('use', 'of')
# ('of',)
# ('of', 'a')
# ('a',)
# ('a', 'book')
# ('book',)
# ('book', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'thought')
# ('thought',)
# ('thought', 'alice')
# ('alice',)
# ('alice', "'")
# ("'",)
# ("'", 'without')
# ('without',)
# ('without', 'pictures')
# ('pictures',)
# ('pictures', 'or')
# ('or',)
# ('or', 'conversation')
# ('conversation',)
# ('conversation', '?')
# ('?',)
# ('?', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'so')
# ('so',)
# ('so', 'she')
# ('she',)
# ('she', 'was')
# ('was',)
# ('was', 'considering')
# ('considering',)
# ('considering', 'in')
# ('in',)
# ('in', 'her')
# ('her',)
# ('her', 'own')
# ('own',)
# ('own', 'mind')
# ('mind',)
# ('mind', '(')
# ('(',)
# ('(', 'as')
# ('as',)
# ('as', 'well')
# ('well',)
# ('well', 'as')
# ('as',)
# ('as', 'she')
# ('she',)
# ('she', 'could')
# ('could',)
# ('could', ',')
# (',',)
# (',', 'for')
# ('for',)
# ('for', 'the')
# ('the',)
# ('the', 'hot')
# ('hot',)
# ('hot', 'day')
# ('day',)
# ('day', 'made')
# ('made',)
# ('made', 'her')
# ('her',)
# ('her', 'feel')
# ('feel',)
# ('feel', 'very')
# ('very',)
# ('very', 'sleepy')
# ('sleepy',)
# ('sleepy', 'and')
# ('and',)
# ('and', 'stupid')
# ('stupid',)
# ('stupid', ')')
# (')',)
# (')', ',')
# (',',)
# (',', 'whether')
# ('whether',)
# ('whether', 'the')
# ('the',)
# ('the', 'pleasure')
# ('pleasure',)
# ('pleasure', 'of')
# ('of',)
# ('of', 'making')
# ('making',)
# ('making', 'a')
# ('a',)
# ('a', 'daisy-chain')
# ('daisy-chain',)
# ('daisy-chain', 'would')
# ('would',)
# ('would', 'be')
# ('be',)
# ('be', 'worth')
# ('worth',)
# ('worth', 'the')
# ('the',)
# ('the', 'trouble')
# ('trouble',)
# ('trouble', 'of')
# ('of',)
# ('of', 'getting')
# ('getting',)
# ('getting', 'up')
# ('up',)
# ('up', 'and')
# ('and',)
# ('and', 'picking')
# ('picking',)
# ('picking', 'the')
# ('the',)
# ('the', 'daisies')
# ('daisies',)
# ('daisies', ',')
# (',',)
# (',', 'when')
# ('when',)
# ('when', 'suddenly')
# ('suddenly',)
# ('suddenly', 'a')
# ('a',)
# ('a', 'white')
# ('white',)
# ('white', 'rabbit')
# ('rabbit',)
# ('rabbit', 'with')
# ('with',)
# ('with', 'pink')
# ('pink',)
# ('pink', 'eyes')
# ('eyes',)
# ('eyes', 'ran')
# ('ran',)
# ('ran', 'close')
# ('close',)
# ('close', 'by')
# ('by',)
# ('by', 'her')
# ('her',)
# ('her', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'there')
# ('there',)
# ('there', 'was')
# ('was',)
# ('was', 'nothing')
# ('nothing',)
# ('nothing', 'so')
# ('so',)
# ('so', 'very')
# ('very',)
# ('very', 'remarkable')
# ('remarkable',)
# ('remarkable', 'in')
# ('in',)
# ('in', 'that')
# ('that',)
# ('that', ';')
# (';',)
# (';', 'nor')
# ('nor',)
# ('nor', 'did')
# ('did',)
# ('did', 'alice')
# ('alice',)
# ('alice', 'think')
# ('think',)
# ('think', 'it')
# ('it',)
# ('it', 'so')
# ('so',)
# ('so', 'very')
# ('very',)
# ('very', 'much')
# ('much',)
# ('much', 'out')
# ('out',)
# ('out', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'way')
# ('way',)
# ('way', 'to')
# ('to',)
# ('to', 'hear')
# ('hear',)
# ('hear', 'the')
# ('the',)
# ('the', 'rabbit')
# ('rabbit',)
# ('rabbit', 'say')
# ('say',)
# ('say', 'to')
# ('to',)
# ('to', 'itself')
# ('itself',)
# ('itself', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'oh')
# ('oh',)
# ('oh', 'dear')
# ('dear',)
# ('dear', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'oh')
# ('oh',)
# ('oh', 'dear')
# ('dear',)
# ('dear', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'i')
# ('i',)
# ('i', 'shall')
# ('shall',)
# ('shall', 'be')
# ('be',)
# ('be', 'late')
# ('late',)
# ('late', '!')
# ('!',)
# ('!', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', '(')
# ('(',)
# ('(', 'when')
# ('when',)
# ('when', 'she')
# ('she',)
# ('she', 'thought')
# ('thought',)
# ('thought', 'it')
# ('it',)
# ('it', 'over')
# ('over',)
# ('over', 'afterwards')
# ('afterwards',)
# ('afterwards', ',')
# (',',)
# (',', 'it')
# ('it',)
# ('it', 'occurred')
# ('occurred',)
# ('occurred', 'to')
# ('to',)
# ('to', 'her')
# ('her',)
# ('her', 'that')
# ('that',)
# ('that', 'she')
# ('she',)
# ('she', 'ought')
# ('ought',)
# ('ought', 'to')
# ('to',)
# ('to', 'have')
# ('have',)
# ('have', 'wondered')
# ('wondered',)
# ('wondered', 'at')
# ('at',)
# ('at', 'this')
# ('this',)
# ('this', ',')
# (',',)
# (',', 'but')
# ('but',)
# ('but', 'at')
# ('at',)
# ('at', 'the')
# ('the',)
# ('the', 'time')
# ('time',)
# ('time', 'it')
# ('it',)
# ('it', 'all')
# ('all',)
# ('all', 'seemed')
# ('seemed',)
# ('seemed', 'quite')
# ('quite',)
# ('quite', 'natural')
# ('natural',)
# ('natural', ');')
# (');',)
# (');', 'but')
# ('but',)
# ('but', 'when')
# ('when',)
# ('when', 'the')
# ('the',)
# ('the', 'rabbit')
# ('rabbit',)
# ('rabbit', 'actually')
# ('actually',)
# ('actually', 'took')
# ('took',)
# ('took', 'a')
# ('a',)
# ('a', 'watch')
# ('watch',)
# ('watch', 'out')
# ('out',)
# ('out', 'of')
# ('of',)
# ('of', 'its')
# ('its',)
# ('its', 'waistcoat-pocket')
# ('waistcoat-pocket',)
# ('waistcoat-pocket', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'looked')
# ('looked',)
# ('looked', 'at')
# ('at',)
# ('at', 'it')
# ('it',)
# ('it', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'then')
# ('then',)
# ('then', 'hurried')
# ('hurried',)
# ('hurried', 'on')
# ('on',)
# ('on', ',')
# (',',)
# (',', 'alice')
# ('alice',)
# ('alice', 'started')
# ('started',)
# ('started', 'to')
# ('to',)
# ('to', 'her')
# ('her',)
# ('her', 'feet')
# ('feet',)
# ('feet', ',')
# (',',)
# (',', 'for')
# ('for',)
# ('for', 'it')
# ('it',)
# ('it', 'flashed')
# ('flashed',)
# ('flashed', 'across')
# ('across',)
# ('across', 'her')
# ('her',)
# ('her', 'mind')
# ('mind',)
# ('mind', 'that')
# ('that',)
# ('that', 'she')
# ('she',)
# ('she', 'had')
# ('had',)
# ('had', 'never')
# ('never',)
# ('never', 'before')
# ('before',)
# ('before', 'seen')
# ('seen',)
# ('seen', 'a')
# ('a',)
# ('a', 'rabbit')
# ('rabbit',)
# ('rabbit', 'with')
# ('with',)
# ('with', 'either')
# ('either',)
# ('either', 'a')
# ('a',)
# ('a', 'waistcoat-pocket')
# ('waistcoat-pocket',)
# ('waistcoat-pocket', ',')
# (',',)
# (',', 'or')
# ('or',)
# ('or', 'a')
# ('a',)
# ('a', 'watch')
# ('watch',)
# ('watch', 'to')
# ('to',)
# ('to', 'take')
# ('take',)
# ('take', 'out')
# ('out',)
# ('out', 'of')
# ('of',)
# ('of', 'it')
# ('it',)
# ('it', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'burning')
# ('burning',)
# ('burning', 'with')
# ('with',)
# ('with', 'curiosity')
# ('curiosity',)
# ('curiosity', ',')
# (',',)
# (',', 'she')
# ('she',)
# ('she', 'ran')
# ('ran',)
# ('ran', 'across')
# ('across',)
# ('across', 'the')
# ('the',)
# ('the', 'field')
# ('field',)
# ('field', 'after')
# ('after',)
# ('after', 'it')
# ('it',)
# ('it', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'fortunately')
# ('fortunately',)
# ('fortunately', 'was')
# ('was',)
# ('was', 'just')
# ('just',)
# ('just', 'in')
# ('in',)
# ('in', 'time')
# ('time',)
# ('time', 'to')
# ('to',)
# ('to', 'see')
# ('see',)
# ('see', 'it')
# ('it',)
# ('it', 'pop')
# ('pop',)
# ('pop', 'down')
# ('down',)
# ('down', 'a')
# ('a',)
# ('a', 'large')
# ('large',)
# ('large', 'rabbit-hole')
# ('rabbit-hole',)
# ('rabbit-hole', 'under')
# ('under',)
# ('under', 'the')
# ('the',)
# ('the', 'hedge')
# ('hedge',)
# ('hedge', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'in')
# ('in',)
# ('in', 'another')
# ('another',)
# ('another', 'moment')
# ('moment',)
# ('moment', 'down')
# ('down',)
# ('down', 'went')
# ('went',)
# ('went', 'alice')
# ('alice',)
# ('alice', 'after')
# ('after',)
# ('after', 'it')
# ('it',)
# ('it', ',')
# (',',)
# (',', 'never')
# ('never',)
# ('never', 'once')
# ('once',)
# ('once', 'considering')
# ('considering',)
# ('considering', 'how')
# ('how',)
# ('how', 'in')
# ('in',)
# ('in', 'the')
# ('the',)
# ('the', 'world')
# ('world',)
# ('world', 'she')
# ('she',)
# ('she', 'was')
# ('was',)
# ('was', 'to')
# ('to',)
# ('to', 'get')
# ('get',)
# ('get', 'out')
# ('out',)
# ('out', 'again')
# ('again',)
# ('again', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'the')
# ('the',)
# ('the', 'rabbit-hole')
# ('rabbit-hole',)
# ('rabbit-hole', 'went')
# ('went',)
# ('went', 'straight')
# ('straight',)
# ('straight', 'on')
# ('on',)
# ('on', 'like')
# ('like',)
# ('like', 'a')
# ('a',)
# ('a', 'tunnel')
# ('tunnel',)
# ('tunnel', 'for')
# ('for',)
# ('for', 'some')
# ('some',)
# ('some', 'way')
# ('way',)
# ('way', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'then')
# ('then',)
# ('then', 'dipped')
# ('dipped',)
# ('dipped', 'suddenly')
# ('suddenly',)
# ('suddenly', 'down')
# ('down',)
# ('down', ',')
# (',',)
# (',', 'so')
# ('so',)
# ('so', 'suddenly')
# ('suddenly',)
# ('suddenly', 'that')
# ('that',)
# ('that', 'alice')
# ('alice',)
# ('alice', 'had')
# ('had',)
# ('had', 'not')
# ('not',)
# ('not', 'a')
# ('a',)
# ('a', 'moment')
# ('moment',)
# ('moment', 'to')
# ('to',)
# ('to', 'think')
# ('think',)
# ('think', 'about')
# ('about',)
# ('about', 'stopping')
# ('stopping',)
# ('stopping', 'herself')
# ('herself',)
# ('herself', 'before')
# ('before',)
# ('before', 'she')
# ('she',)
# ('she', 'found')
# ('found',)
# ('found', 'herself')
# ('herself',)
# ('herself', 'falling')
# ('falling',)
# ('falling', 'down')
# ('down',)
# ('down', 'a')
# ('a',)
# ('a', 'very')
# ('very',)
# ('very', 'deep')
# ('deep',)
# ('deep', 'well')
# ('well',)
# ('well', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'either')
# ('either',)
# ('either', 'the')
# ('the',)
# ('the', 'well')
# ('well',)
# ('well', 'was')
# ('was',)
# ('was', 'very')
# ('very',)
# ('very', 'deep')
# ('deep',)
# ('deep', ',')
# (',',)
# (',', 'or')
# ('or',)
# ('or', 'she')
# ('she',)
# ('she', 'fell')
# ('fell',)
# ('fell', 'very')
# ('very',)
# ('very', 'slowly')
# ('slowly',)
# ('slowly', ',')
# (',',)
# (',', 'for')
# ('for',)
# ('for', 'she')
# ('she',)
# ('she', 'had')
# ('had',)
# ('had', 'plenty')
# ('plenty',)
# ('plenty', 'of')
# ('of',)
# ('of', 'time')
# ('time',)
# ('time', 'as')
# ('as',)
# ('as', 'she')
# ('she',)
# ('she', 'went')
# ('went',)
# ('went', 'down')
# ('down',)
# ('down', 'to')
# ('to',)
# ('to', 'look')
# ('look',)
# ('look', 'about')
# ('about',)
# ('about', 'her')
# ('her',)
# ('her', 'and')
# ('and',)
# ('and', 'to')
# ('to',)
# ('to', 'wonder')
# ('wonder',)
# ('wonder', 'what')
# ('what',)
# ('what', 'was')
# ('was',)
# ('was', 'going')
# ('going',)
# ('going', 'to')
# ('to',)
# ('to', 'happen')
# ('happen',)
# ('happen', 'next')
# ('next',)
# ('next', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'first')
# ('first',)
# ('first', ',')
# (',',)
# (',', 'she')
# ('she',)
# ('she', 'tried')
# ('tried',)
# ('tried', 'to')
# ('to',)
# ('to', 'look')
# ('look',)
# ('look', 'down')
# ('down',)
# ('down', 'and')
# ('and',)
# ('and', 'make')
# ('make',)
# ('make', 'out')
# ('out',)
# ('out', 'what')
# ('what',)
# ('what', 'she')
# ('she',)
# ('she', 'was')
# ('was',)
# ('was', 'coming')
# ('coming',)
# ('coming', 'to')
# ('to',)
# ('to', ',')
# (',',)
# (',', 'but')
# ('but',)
# ('but', 'it')
# ('it',)
# ('it', 'was')
# ('was',)
# ('was', 'too')
# ('too',)
# ('too', 'dark')
# ('dark',)
# ('dark', 'to')
# ('to',)
# ('to', 'see')
# ('see',)
# ('see', 'anything')
# ('anything',)
# ('anything', ';')
# (';',)
# (';', 'then')
# ('then',)
# ('then', 'she')
# ('she',)
# ('she', 'looked')
# ('looked',)
# ('looked', 'at')
# ('at',)
# ('at', 'the')
# ('the',)
# ('the', 'sides')
# ('sides',)
# ('sides', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'well')
# ('well',)
# ('well', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'noticed')
# ('noticed',)
# ('noticed', 'that')
# ('that',)
# ('that', 'they')
# ('they',)
# ('they', 'were')
# ('were',)
# ('were', 'filled')
# ('filled',)
# ('filled', 'with')
# ('with',)
# ('with', 'cupboards')
# ('cupboards',)
# ('cupboards', 'and')
# ('and',)
# ('and', 'book-shelves')
# ('book-shelves',)
# ('book-shelves', ';')
# (';',)
# (';', 'here')
# ('here',)
# ('here', 'and')
# ('and',)
# ('and', 'there')
# ('there',)
# ('there', 'she')
# ('she',)
# ('she', 'saw')
# ('saw',)
# ('saw', 'maps')
# ('maps',)
# ('maps', 'and')
# ('and',)
# ('and', 'pictures')
# ('pictures',)
# ('pictures', 'hung')
# ('hung',)
# ('hung', 'upon')
# ('upon',)
# ('upon', 'pegs')
# ('pegs',)
# ('pegs', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'she')
# ('she',)
# ('she', 'took')
# ('took',)
# ('took', 'down')
# ('down',)
# ('down', 'a')
# ('a',)
# ('a', 'jar')
# ('jar',)
# ('jar', 'from')
# ('from',)
# ('from', 'one')
# ('one',)
# ('one', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'shelves')
# ('shelves',)
# ('shelves', 'as')
# ('as',)
# ('as', 'she')
# ('she',)
# ('she', 'passed')
# ('passed',)
# ('passed', ';')
# (';',)
# (';', 'it')
# ('it',)
# ('it', 'was')
# ('was',)
# ('was', 'labelled')
# ('labelled',)
# ('labelled', "'")
# ("'",)
# ("'", 'orange')
# ('orange',)
# ('orange', 'marmalade')
# ('marmalade',)
# ('marmalade', "'")
# ("'",)
# ("'", ',')
# (',',)
# (',', 'but')
# ('but',)
# ('but', 'to')
# ('to',)
# ('to', 'her')
# ('her',)
# ('her', 'great')
# ('great',)
# ('great', 'disappointment')
# ('disappointment',)
# ('disappointment', 'it')
# ('it',)
# ('it', 'was')
# ('was',)
# ('was', 'empty')
# ('empty',)
# ('empty', ':')
# (':',)
# (':', 'she')
# ('she',)
# ('she', 'did')
# ('did',)
# ('did', 'not')
# ('not',)
# ('not', 'like')
# ('like',)
# ('like', 'to')
# ('to',)
# ('to', 'drop')
# ('drop',)
# ('drop', 'the')
# ('the',)
# ('the', 'jar')
# ('jar',)
# ('jar', 'for')
# ('for',)
# ('for', 'fear')
# ('fear',)
# ('fear', 'of')
# ('of',)
# ('of', 'killing')
# ('killing',)
# ('killing', 'somebody')
# ('somebody',)
# ('somebody', ',')
# (',',)
# (',', 'so')
# ('so',)
# ('so', 'managed')
# ('managed',)
# ('managed', 'to')
# ('to',)
# ('to', 'put')
# ('put',)
# ('put', 'it')
# ('it',)
# ('it', 'into')
# ('into',)
# ('into', 'one')
# ('one',)
# ('one', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'cupboards')
# ('cupboards',)
# ('cupboards', 'as')
# ('as',)
# ('as', 'she')
# ('she',)
# ('she', 'fell')
# ('fell',)
# ('fell', 'past')
# ('past',)
# ('past', 'it')
# ('it',)
# ('it', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', "'")
# ("'",)
# ("'", 'well')
# ('well',)
# ('well', '!')
# ('!',)
# ('!', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'thought')
# ('thought',)
# ('thought', 'alice')
# ('alice',)
# ('alice', 'to')
# ('to',)
# ('to', 'herself')
# ('herself',)
# ('herself', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'after')
# ('after',)
# ('after', 'such')
# ('such',)
# ('such', 'a')
# ('a',)
# ('a', 'fall')
# ('fall',)
# ('fall', 'as')
# ('as',)
# ('as', 'this')
# ('this',)
# ('this', ',')
# (',',)
# (',', 'i')
# ('i',)
# ('i', 'shall')
# ('shall',)
# ('shall', 'think')
# ('think',)
# ('think', 'nothing')
# ('nothing',)
# ('nothing', 'of')
# ('of',)
# ('of', 'tumbling')
# ('tumbling',)
# ('tumbling', 'down')
# ('down',)
# ('down', 'stairs')
# ('stairs',)
# ('stairs', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'how')
# ('how',)
# ('how', 'brave')
# ('brave',)
# ('brave', "they'll")
# ("they'll",)
# ("they'll", 'all')
# ('all',)
# ('all', 'think')
# ('think',)
# ('think', 'me')
# ('me',)
# ('me', 'at')
# ('at',)
# ('at', 'home')
# ('home',)
# ('home', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'why')
# ('why',)
# ('why', ',')
# (',',)
# (',', 'i')
# ('i',)
# ('i', "wouldn't")
# ("wouldn't",)
# ("wouldn't", 'say')
# ('say',)
# ('say', 'anything')
# ('anything',)
# ('anything', 'about')
# ('about',)
# ('about', 'it')
# ('it',)
# ('it', ',')
# (',',)
# (',', 'even')
# ('even',)
# ('even', 'if')
# ('if',)
# ('if', 'i')
# ('i',)
# ('i', 'fell')
# ('fell',)
# ('fell', 'off')
# ('off',)
# ('off', 'the')
# ('the',)
# ('the', 'top')
# ('top',)
# ('top', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'house')
# ('house',)
# ('house', '!')
# ('!',)
# ('!', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', '(')
# ('(',)
# ('(', 'which')
# ('which',)
# ('which', 'was')
# ('was',)
# ('was', 'very')
# ('very',)
# ('very', 'likely')
# ('likely',)
# ('likely', 'true')
# ('true',)
# ('true', '.')
# ('.',)
# ('.', ')')
# (')',)
# (')', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'down')
# ('down',)
# ('down', ',')
# (',',)
# (',', 'down')
# ('down',)
# ('down', ',')
# (',',)
# (',', 'down')
# ('down',)
# ('down', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'would')
# ('would',)
# ('would', 'the')
# ('the',)
# ('the', 'fall')
# ('fall',)
# ('fall', 'never')
# ('never',)
# ('never', 'come')
# ('come',)
# ('come', 'to')
# ('to',)
# ('to', 'an')
# ('an',)
# ('an', 'end')
# ('end',)
# ('end', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', "'")
# ("'",)
# ("'", 'i')
# ('i',)
# ('i', 'wonder')
# ('wonder',)
# ('wonder', 'how')
# ('how',)
# ('how', 'many')
# ('many',)
# ('many', 'miles')
# ('miles',)
# ('miles', "i've")
# ("i've",)
# ("i've", 'fallen')
# ('fallen',)
# ('fallen', 'by')
# ('by',)
# ('by', 'this')
# ('this',)
# ('this', 'time')
# ('time',)
# ('time', '?')
# ('?',)
# ('?', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'she')
# ('she',)
# ('she', 'said')
# ('said',)
# ('said', 'aloud')
# ('aloud',)
# ('aloud', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', "'")
# ("'",)
# ("'", 'i')
# ('i',)
# ('i', 'must')
# ('must',)
# ('must', 'be')
# ('be',)
# ('be', 'getting')
# ('getting',)
# ('getting', 'somewhere')
# ('somewhere',)
# ('somewhere', 'near')
# ('near',)
# ('near', 'the')
# ('the',)
# ('the', 'centre')
# ('centre',)
# ('centre', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'earth')
# ('earth',)
# ('earth', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'let')
# ('let',)
# ('let', 'me')
# ('me',)
# ('me', 'see')
# ('see',)
# ('see', ':')
# (':',)
# (':', 'that')
# ('that',)
# ('that', 'would')
# ('would',)
# ('would', 'be')
# ('be',)
# ('be', 'four')
# ('four',)
# ('four', 'thousand')
# ('thousand',)
# ('thousand', 'miles')
# ('miles',)
# ('miles', 'down')
# ('down',)
# ('down', ',')
# (',',)
# (',', 'i')
# ('i',)
# ('i', 'think')
# ('think',)
# ('think', '-')
# ('-',)
# ('-', '-')
# ('-',)
# ('-', "'")
# ("'",)
# ("'", '(')
# ('(',)
# ('(', 'for')
# ('for',)
# ('for', ',')
# (',',)
# (',', 'you')
# ('you',)
# ('you', 'see')
# ('see',)
# ('see', ',')
# (',',)
# (',', 'alice')
# ('alice',)
# ('alice', 'had')
# ('had',)
# ('had', 'learnt')
# ('learnt',)
# ('learnt', 'several')
# ('several',)
# ('several', 'things')
# ('things',)
# ('things', 'of')
# ('of',)
# ('of', 'this')
# ('this',)
# ('this', 'sort')
# ('sort',)
# ('sort', 'in')
# ('in',)
# ('in', 'her')
# ('her',)
# ('her', 'lessons')
# ('lessons',)
# ('lessons', 'in')
# ('in',)
# ('in', 'the')
# ('the',)
# ('the', 'schoolroom')
# ('schoolroom',)
# ('schoolroom', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'though')
# ('though',)
# ('though', 'this')
# ('this',)
# ('this', 'was')
# ('was',)
# ('was', 'not')
# ('not',)
# ('not', 'a')
# ('a',)
# ('a', 'very')
# ('very',)
# ('very', 'good')
# ('good',)
# ('good', 'opportunity')
# ('opportunity',)
# ('opportunity', 'for')
# ('for',)
# ('for', 'showing')
# ('showing',)
# ('showing', 'off')
# ('off',)
# ('off', 'her')
# ('her',)
# ('her', 'knowledge')
# ('knowledge',)
# ('knowledge', ',')
# (',',)
# (',', 'as')
# ('as',)
# ('as', 'there')
# ('there',)
# ('there', 'was')
# ('was',)
# ('was', 'no')
# ('no',)
# ('no', 'one')
# ('one',)
# ('one', 'to')
# ('to',)
# ('to', 'listen')
# ('listen',)
# ('listen', 'to')
# ('to',)
# ('to', 'her')
# ('her',)
# ('her', ',')
# (',',)
# (',', 'still')
# ('still',)
# ('still', 'it')
# ('it',)
# ('it', 'was')
# ('was',)
# ('was', 'good')
# ('good',)
# ('good', 'practice')
# ('practice',)
# ('practice', 'to')
# ('to',)
# ('to', 'say')
# ('say',)
# ('say', 'it')
# ('it',)
# ('it', 'over')
# ('over',)
# ('over', ')')
# (')',)
# (')', "'")
# ("'",)
# ("'", '-')
# ('-',)
# ('-', '-')
# ('-',)
# ('-', 'yes')
# ('yes',)
# ('yes', ',')
# (',',)
# (',', "that's")
# ("that's",)
# ("that's", 'about')
# ('about',)
# ('about', 'the')
# ('the',)
# ('the', 'right')
# ('right',)
# ('right', 'distance--but')
# ('distance--but',)
# ('distance--but', 'then')
# ('then',)
# ('then', 'i')
# ('i',)
# ('i', 'wonder')
# ('wonder',)
# ('wonder', 'what')
# ('what',)
# ('what', 'latitude')
# ('latitude',)
# ('latitude', 'or')
# ('or',)
# ('or', 'longitude')
# ('longitude',)
# ('longitude', "i've")
# ("i've",)
# ("i've", 'got')
# ('got',)
# ('got', 'to')
# ('to',)
# ('to', '?')
# ('?',)
# ('?', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', '(')
# ('(',)
# ('(', 'alice')
# ('alice',)
# ('alice', 'had')
# ('had',)
# ('had', 'no')
# ('no',)
# ('no', 'idea')
# ('idea',)
# ('idea', 'what')
# ('what',)
# ('what', 'latitude')
# ('latitude',)
# ('latitude', 'was')
# ('was',)
# ('was', ',')
# (',',)
# (',', 'or')
# ('or',)
# ('or', 'longitude')
# ('longitude',)
# ('longitude', 'either')
# ('either',)
# ('either', ',')
# (',',)
# (',', 'but')
# ('but',)
# ('but', 'thought')
# ('thought',)
# ('thought', 'they')
# ('they',)
# ('they', 'were')
# ('were',)
# ('were', 'nice')
# ('nice',)
# ('nice', 'grand')
# ('grand',)
# ('grand', 'words')
# ('words',)
# ('words', 'to')
# ('to',)
# ('to', 'say')
# ('say',)
# ('say', '.')
# ('.',)
# ('.', ')')
# (')',)
# (')', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'presently')
# ('presently',)
# ('presently', 'she')
# ('she',)
# ('she', 'began')
# ('began',)
# ('began', 'again')
# ('again',)
# ('again', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', "'")
# ("'",)
# ("'", 'i')
# ('i',)
# ('i', 'wonder')
# ('wonder',)
# ('wonder', 'if')
# ('if',)
# ('if', 'i')
# ('i',)
# ('i', 'shall')
# ('shall',)
# ('shall', 'fall')
# ('fall',)
# ('fall', 'right')
# ('right',)
# ('right', 'through')
# ('through',)
# ('through', 'the')
# ('the',)
# ('the', 'earth')
# ('earth',)
# ('earth', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'how')
# ('how',)
# ('how', 'funny')
# ('funny',)
# ('funny', "it'll")
# ("it'll",)
# ("it'll", 'seem')
# ('seem',)
# ('seem', 'to')
# ('to',)
# ('to', 'come')
# ('come',)
# ('come', 'out')
# ('out',)
# ('out', 'among')
# ('among',)
# ('among', 'the')
# ('the',)
# ('the', 'people')
# ('people',)
# ('people', 'that')
# ('that',)
# ('that', 'walk')
# ('walk',)
# ('walk', 'with')
# ('with',)
# ('with', 'their')
# ('their',)
# ('their', 'heads')
# ('heads',)
# ('heads', 'downward')
# ('downward',)
# ('downward', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'the')
# ('the',)
# ('the', 'antipathies')
# ('antipathies',)
# ('antipathies', ',')
# (',',)
# (',', 'i')
# ('i',)
# ('i', 'think')
# ('think',)
# ('think', '-')
# ('-',)
# ('-', '-')
# ('-',)
# ('-', "'")
# ("'",)
# ("'", '(')
# ('(',)
# ('(', 'she')
# ('she',)
# ('she', 'was')
# ('was',)
# ('was', 'rather')
# ('rather',)
# ('rather', 'glad')
# ('glad',)
# ('glad', 'there')
# ('there',)
# ('there', 'was')
# ('was',)
# ('was', 'no')
# ('no',)
# ('no', 'one')
# ('one',)
# ('one', 'listening')
# ('listening',)
# ('listening', ',')
# (',',)
# (',', 'this')
# ('this',)
# ('this', 'time')
# ('time',)
# ('time', ',')
# (',',)
# (',', 'as')
# ('as',)
# ('as', 'it')
# ('it',)
# ('it', "didn't")
# ("didn't",)
# ("didn't", 'sound')
# ('sound',)
# ('sound', 'at')
# ('at',)
# ('at', 'all')
# ('all',)
# ('all', 'the')
# ('the',)
# ('the', 'right')
# ('right',)
# ('right', 'word')
# ('word',)
# ('word', ')')
# (')',)
# (')', "'")
# ("'",)
# ("'", '-')
# ('-',)
# ('-', '-')
# ('-',)
# ('-', 'but')
# ('but',)
# ('but', 'i')
# ('i',)
# ('i', 'shall')
# ('shall',)
# ('shall', 'have')
# ('have',)
# ('have', 'to')
# ('to',)
# ('to', 'ask')
# ('ask',)
# ('ask', 'them')
# ('them',)
# ('them', 'what')
# ('what',)
# ('what', 'the')
# ('the',)
# ('the', 'name')
# ('name',)
# ('name', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'country')
# ('country',)
# ('country', 'is')
# ('is',)
# ('is', ',')
# (',',)
# (',', 'you')
# ('you',)
# ('you', 'know')
# ('know',)
# ('know', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'please')
# ('please',)
# ('please', ',')
# (',',)
# (',', "ma'am")
# ("ma'am",)
# ("ma'am", ',')
# (',',)
# (',', 'is')
# ('is',)
# ('is', 'this')
# ('this',)
# ('this', 'new')
# ('new',)
# ('new', 'zealand')
# ('zealand',)
# ('zealand', 'or')
# ('or',)
# ('or', 'australia')
# ('australia',)
# ('australia', '?')
# ('?',)
# ('?', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', '(')
# ('(',)
# ('(', 'and')
# ('and',)
# ('and', 'she')
# ('she',)
# ('she', 'tried')
# ('tried',)
# ('tried', 'to')
# ('to',)
# ('to', 'curtsey')
# ('curtsey',)
# ('curtsey', 'as')
# ('as',)
# ('as', 'she')
# ('she',)
# ('she', 'spoke--fancy')
# ('spoke--fancy',)
# ('spoke--fancy', 'curtseying')
# ('curtseying',)
# ('curtseying', 'as')
# ('as',)
# ('as', "you're")
# ("you're",)
# ("you're", 'falling')
# ('falling',)
# ('falling', 'through')
# ('through',)
# ('through', 'the')
# ('the',)
# ('the', 'air')
# ('air',)
# ('air', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'do')
# ('do',)
# ('do', 'you')
# ('you',)
# ('you', 'think')
# ('think',)
# ('think', 'you')
# ('you',)
# ('you', 'could')
# ('could',)
# ('could', 'manage')
# ('manage',)
# ('manage', 'it')
# ('it',)
# ('it', '?')
# ('?',)
# ('?', ')')
# (')',)
# (')', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', "'")
# ("'",)
# ("'", 'and')
# ('and',)
# ('and', 'what')
# ('what',)
# ('what', 'an')
# ('an',)
# ('an', 'ignorant')
# ('ignorant',)
# ('ignorant', 'little')
# ('little',)
# ('little', 'girl')
# ('girl',)
# ('girl', "she'll")
# ("she'll",)
# ("she'll", 'think')
# ('think',)
# ('think', 'me')
# ('me',)
# ('me', 'for')
# ('for',)
# ('for', 'asking')
# ('asking',)
# ('asking', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'no')
# ('no',)
# ('no', ',')
# (',',)
# (',', "it'll")
# ("it'll",)
# ("it'll", 'never')
# ('never',)
# ('never', 'do')
# ('do',)
# ('do', 'to')
# ('to',)
# ('to', 'ask')
# ('ask',)
# ('ask', ':')
# (':',)
# (':', 'perhaps')
# ('perhaps',)
# ('perhaps', 'i')
# ('i',)
# ('i', 'shall')
# ('shall',)
# ('shall', 'see')
# ('see',)
# ('see', 'it')
# ('it',)
# ('it', 'written')
# ('written',)
# ('written', 'up')
# ('up',)
# ('up', 'somewhere')
# ('somewhere',)
# ('somewhere', '.')
# ('.',)
# ('.', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'down')
# ('down',)
# ('down', ',')
# (',',)
# (',', 'down')
# ('down',)
# ('down', ',')
# (',',)
# (',', 'down')
# ('down',)
# ('down', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'there')
# ('there',)
# ('there', 'was')
# ('was',)
# ('was', 'nothing')
# ('nothing',)
# ('nothing', 'else')
# ('else',)
# ('else', 'to')
# ('to',)
# ('to', 'do')
# ('do',)
# ('do', ',')
# (',',)
# (',', 'so')
# ('so',)
# ('so', 'alice')
# ('alice',)
# ('alice', 'soon')
# ('soon',)
# ('soon', 'began')
# ('began',)
# ('began', 'talking')
# ('talking',)
# ('talking', 'again')
# ('again',)
# ('again', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', "'")
# ("'",)
# ("'", "dinah'll")
# ("dinah'll",)
# ("dinah'll", 'miss')
# ('miss',)
# ('miss', 'me')
# ('me',)
# ('me', 'very')
# ('very',)
# ('very', 'much')
# ('much',)
# ('much', 'to-night')
# ('to-night',)
# ('to-night', ',')
# (',',)
# (',', 'i')
# ('i',)
# ('i', 'should')
# ('should',)
# ('should', 'think')
# ('think',)
# ('think', '!')
# ('!',)
# ('!', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', '(')
# ('(',)
# ('(', 'dinah')
# ('dinah',)
# ('dinah', 'was')
# ('was',)
# ('was', 'the')
# ('the',)
# ('the', 'cat')
# ('cat',)
# ('cat', '.')
# ('.',)
# ('.', ')')
# (')',)
# (')', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', "'")
# ("'",)
# ("'", 'i')
# ('i',)
# ('i', 'hope')
# ('hope',)
# ('hope', "they'll")
# ("they'll",)
# ("they'll", 'remember')
# ('remember',)
# ('remember', 'her')
# ('her',)
# ('her', 'saucer')
# ('saucer',)
# ('saucer', 'of')
# ('of',)
# ('of', 'milk')
# ('milk',)
# ('milk', 'at')
# ('at',)
# ('at', 'tea-time')
# ('tea-time',)
# ('tea-time', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'dinah')
# ('dinah',)
# ('dinah', 'my')
# ('my',)
# ('my', 'dear')
# ('dear',)
# ('dear', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'i')
# ('i',)
# ('i', 'wish')
# ('wish',)
# ('wish', 'you')
# ('you',)
# ('you', 'were')
# ('were',)
# ('were', 'down')
# ('down',)
# ('down', 'here')
# ('here',)
# ('here', 'with')
# ('with',)
# ('with', 'me')
# ('me',)
# ('me', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'there')
# ('there',)
# ('there', 'are')
# ('are',)
# ('are', 'no')
# ('no',)
# ('no', 'mice')
# ('mice',)
# ('mice', 'in')
# ('in',)
# ('in', 'the')
# ('the',)
# ('the', 'air')
# ('air',)
# ('air', ',')
# (',',)
# (',', "i'm")
# ("i'm",)
# ("i'm", 'afraid')
# ('afraid',)
# ('afraid', ',')
# (',',)
# (',', 'but')
# ('but',)
# ('but', 'you')
# ('you',)
# ('you', 'might')
# ('might',)
# ('might', 'catch')
# ('catch',)
# ('catch', 'a')
# ('a',)
# ('a', 'bat')
# ('bat',)
# ('bat', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', "that's")
# ("that's",)
# ("that's", 'very')
# ('very',)
# ('very', 'like')
# ('like',)
# ('like', 'a')
# ('a',)
# ('a', 'mouse')
# ('mouse',)
# ('mouse', ',')
# (',',)
# (',', 'you')
# ('you',)
# ('you', 'know')
# ('know',)
# ('know', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'but')
# ('but',)
# ('but', 'do')
# ('do',)
# ('do', 'cats')
# ('cats',)
# ('cats', 'eat')
# ('eat',)
# ('eat', 'bats')
# ('bats',)
# ('bats', ',')
# (',',)
# (',', 'i')
# ('i',)
# ('i', 'wonder')
# ('wonder',)
# ('wonder', '?')
# ('?',)
# ('?', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'and')
# ('and',)
# ('and', 'here')
# ('here',)
# ('here', 'alice')
# ('alice',)
# ('alice', 'began')
# ('began',)
# ('began', 'to')
# ('to',)
# ('to', 'get')
# ('get',)
# ('get', 'rather')
# ('rather',)
# ('rather', 'sleepy')
# ('sleepy',)
# ('sleepy', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'went')
# ('went',)
# ('went', 'on')
# ('on',)
# ('on', 'saying')
# ('saying',)
# ('saying', 'to')
# ('to',)
# ('to', 'herself')
# ('herself',)
# ('herself', ',')
# (',',)
# (',', 'in')
# ('in',)
# ('in', 'a')
# ('a',)
# ('a', 'dreamy')
# ('dreamy',)
# ('dreamy', 'sort')
# ('sort',)
# ('sort', 'of')
# ('of',)
# ('of', 'way')
# ('way',)
# ('way', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'do')
# ('do',)
# ('do', 'cats')
# ('cats',)
# ('cats', 'eat')
# ('eat',)
# ('eat', 'bats')
# ('bats',)
# ('bats', '?')
# ('?',)
# ('?', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'do')
# ('do',)
# ('do', 'cats')
# ('cats',)
# ('cats', 'eat')
# ('eat',)
# ('eat', 'bats')
# ('bats',)
# ('bats', '?')
# ('?',)
# ('?', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'and')
# ('and',)
# ('and', 'sometimes')
# ('sometimes',)
# ('sometimes', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'do')
# ('do',)
# ('do', 'bats')
# ('bats',)
# ('bats', 'eat')
# ('eat',)
# ('eat', 'cats')
# ('cats',)
# ('cats', '?')
# ('?',)
# ('?', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'for')
# ('for',)
# ('for', ',')
# (',',)
# (',', 'you')
# ('you',)
# ('you', 'see')
# ('see',)
# ('see', ',')
# (',',)
# (',', 'as')
# ('as',)
# ('as', 'she')
# ('she',)
# ('she', "couldn't")
# ("couldn't",)
# ("couldn't", 'answer')
# ('answer',)
# ('answer', 'either')
# ('either',)
# ('either', 'question')
# ('question',)
# ('question', ',')
# (',',)
# (',', 'it')
# ('it',)
# ('it', "didn't")
# ("didn't",)
# ("didn't", 'much')
# ('much',)
# ('much', 'matter')
# ('matter',)
# ('matter', 'which')
# ('which',)
# ('which', 'way')
# ('way',)
# ('way', 'she')
# ('she',)
# ('she', 'put')
# ('put',)
# ('put', 'it')
# ('it',)
# ('it', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'she')
# ('she',)
# ('she', 'felt')
# ('felt',)
# ('felt', 'that')
# ('that',)
# ('that', 'she')
# ('she',)
# ('she', 'was')
# ('was',)
# ('was', 'dozing')
# ('dozing',)
# ('dozing', 'off')
# ('off',)
# ('off', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'had')
# ('had',)
# ('had', 'just')
# ('just',)
# ('just', 'begun')
# ('begun',)
# ('begun', 'to')
# ('to',)
# ('to', 'dream')
# ('dream',)
# ('dream', 'that')
# ('that',)
# ('that', 'she')
# ('she',)
# ('she', 'was')
# ('was',)
# ('was', 'walking')
# ('walking',)
# ('walking', 'hand')
# ('hand',)
# ('hand', 'in')
# ('in',)
# ('in', 'hand')
# ('hand',)
# ('hand', 'with')
# ('with',)
# ('with', 'dinah')
# ('dinah',)
# ('dinah', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'saying')
# ('saying',)
# ('saying', 'to')
# ('to',)
# ('to', 'her')
# ('her',)
# ('her', 'very')
# ('very',)
# ('very', 'earnestly')
# ('earnestly',)
# ('earnestly', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'now')
# ('now',)
# ('now', ',')
# (',',)
# (',', 'dinah')
# ('dinah',)
# ('dinah', ',')
# (',',)
# (',', 'tell')
# ('tell',)
# ('tell', 'me')
# ('me',)
# ('me', 'the')
# ('the',)
# ('the', 'truth')
# ('truth',)
# ('truth', ':')
# (':',)
# (':', 'did')
# ('did',)
# ('did', 'you')
# ('you',)
# ('you', 'ever')
# ('ever',)
# ('ever', 'eat')
# ('eat',)
# ('eat', 'a')
# ('a',)
# ('a', 'bat')
# ('bat',)
# ('bat', '?')
# ('?',)
# ('?', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'when')
# ('when',)
# ('when', 'suddenly')
# ('suddenly',)
# ('suddenly', ',')
# (',',)
# (',', 'thump')
# ('thump',)
# ('thump', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'thump')
# ('thump',)
# ('thump', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'down')
# ('down',)
# ('down', 'she')
# ('she',)
# ('she', 'came')
# ('came',)
# ('came', 'upon')
# ('upon',)
# ('upon', 'a')
# ('a',)
# ('a', 'heap')
# ('heap',)
# ('heap', 'of')
# ('of',)
# ('of', 'sticks')
# ('sticks',)
# ('sticks', 'and')
# ('and',)
# ('and', 'dry')
# ('dry',)
# ('dry', 'leaves')
# ('leaves',)
# ('leaves', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'the')
# ('the',)
# ('the', 'fall')
# ('fall',)
# ('fall', 'was')
# ('was',)
# ('was', 'over')
# ('over',)
# ('over', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'alice')
# ('alice',)
# ('alice', 'was')
# ('was',)
# ('was', 'not')
# ('not',)
# ('not', 'a')
# ('a',)
# ('a', 'bit')
# ('bit',)
# ('bit', 'hurt')
# ('hurt',)
# ('hurt', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'she')
# ('she',)
# ('she', 'jumped')
# ('jumped',)
# ('jumped', 'up')
# ('up',)
# ('up', 'on')
# ('on',)
# ('on', 'to')
# ('to',)
# ('to', 'her')
# ('her',)
# ('her', 'feet')
# ('feet',)
# ('feet', 'in')
# ('in',)
# ('in', 'a')
# ('a',)
# ('a', 'moment')
# ('moment',)
# ('moment', ':')
# (':',)
# (':', 'she')
# ('she',)
# ('she', 'looked')
# ('looked',)
# ('looked', 'up')
# ('up',)
# ('up', ',')
# (',',)
# (',', 'but')
# ('but',)
# ('but', 'it')
# ('it',)
# ('it', 'was')
# ('was',)
# ('was', 'all')
# ('all',)
# ('all', 'dark')
# ('dark',)
# ('dark', 'overhead')
# ('overhead',)
# ('overhead', ';')
# (';',)
# (';', 'before')
# ('before',)
# ('before', 'her')
# ('her',)
# ('her', 'was')
# ('was',)
# ('was', 'another')
# ('another',)
# ('another', 'long')
# ('long',)
# ('long', 'passage')
# ('passage',)
# ('passage', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'the')
# ('the',)
# ('the', 'white')
# ('white',)
# ('white', 'rabbit')
# ('rabbit',)
# ('rabbit', 'was')
# ('was',)
# ('was', 'still')
# ('still',)
# ('still', 'in')
# ('in',)
# ('in', 'sight')
# ('sight',)
# ('sight', ',')
# (',',)
# (',', 'hurrying')
# ('hurrying',)
# ('hurrying', 'down')
# ('down',)
# ('down', 'it')
# ('it',)
# ('it', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'there')
# ('there',)
# ('there', 'was')
# ('was',)
# ('was', 'not')
# ('not',)
# ('not', 'a')
# ('a',)
# ('a', 'moment')
# ('moment',)
# ('moment', 'to')
# ('to',)
# ('to', 'be')
# ('be',)
# ('be', 'lost')
# ('lost',)
# ('lost', ':')
# (':',)
# (':', 'away')
# ('away',)
# ('away', 'went')
# ('went',)
# ('went', 'alice')
# ('alice',)
# ('alice', 'like')
# ('like',)
# ('like', 'the')
# ('the',)
# ('the', 'wind')
# ('wind',)
# ('wind', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'was')
# ('was',)
# ('was', 'just')
# ('just',)
# ('just', 'in')
# ('in',)
# ('in', 'time')
# ('time',)
# ('time', 'to')
# ('to',)
# ('to', 'hear')
# ('hear',)
# ('hear', 'it')
# ('it',)
# ('it', 'say')
# ('say',)
# ('say', ',')
# (',',)
# (',', 'as')
# ('as',)
# ('as', 'it')
# ('it',)
# ('it', 'turned')
# ('turned',)
# ('turned', 'a')
# ('a',)
# ('a', 'corner')
# ('corner',)
# ('corner', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'oh')
# ('oh',)
# ('oh', 'my')
# ('my',)
# ('my', 'ears')
# ('ears',)
# ('ears', 'and')
# ('and',)
# ('and', 'whiskers')
# ('whiskers',)
# ('whiskers', ',')
# (',',)
# (',', 'how')
# ('how',)
# ('how', 'late')
# ('late',)
# ('late', "it's")
# ("it's",)
# ("it's", 'getting')
# ('getting',)
# ('getting', '!')
# ('!',)
# ('!', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'she')
# ('she',)
# ('she', 'was')
# ('was',)
# ('was', 'close')
# ('close',)
# ('close', 'behind')
# ('behind',)
# ('behind', 'it')
# ('it',)
# ('it', 'when')
# ('when',)
# ('when', 'she')
# ('she',)
# ('she', 'turned')
# ('turned',)
# ('turned', 'the')
# ('the',)
# ('the', 'corner')
# ('corner',)
# ('corner', ',')
# (',',)
# (',', 'but')
# ('but',)
# ('but', 'the')
# ('the',)
# ('the', 'rabbit')
# ('rabbit',)
# ('rabbit', 'was')
# ('was',)
# ('was', 'no')
# ('no',)
# ('no', 'longer')
# ('longer',)
# ('longer', 'to')
# ('to',)
# ('to', 'be')
# ('be',)
# ('be', 'seen')
# ('seen',)
# ('seen', ':')
# (':',)
# (':', 'she')
# ('she',)
# ('she', 'found')
# ('found',)
# ('found', 'herself')
# ('herself',)
# ('herself', 'in')
# ('in',)
# ('in', 'a')
# ('a',)
# ('a', 'long')
# ('long',)
# ('long', ',')
# (',',)
# (',', 'low')
# ('low',)
# ('low', 'hall')
# ('hall',)
# ('hall', ',')
# (',',)
# (',', 'which')
# ('which',)
# ('which', 'was')
# ('was',)
# ('was', 'lit')
# ('lit',)
# ('lit', 'up')
# ('up',)
# ('up', 'by')
# ('by',)
# ('by', 'a')
# ('a',)
# ('a', 'row')
# ('row',)
# ('row', 'of')
# ('of',)
# ('of', 'lamps')
# ('lamps',)
# ('lamps', 'hanging')
# ('hanging',)
# ('hanging', 'from')
# ('from',)
# ('from', 'the')
# ('the',)
# ('the', 'roof')
# ('roof',)
# ('roof', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'there')
# ('there',)
# ('there', 'were')
# ('were',)
# ('were', 'doors')
# ('doors',)
# ('doors', 'all')
# ('all',)
# ('all', 'round')
# ('round',)
# ('round', 'the')
# ('the',)
# ('the', 'hall')
# ('hall',)
# ('hall', ',')
# (',',)
# (',', 'but')
# ('but',)
# ('but', 'they')
# ('they',)
# ('they', 'were')
# ('were',)
# ('were', 'all')
# ('all',)
# ('all', 'locked')
# ('locked',)
# ('locked', ';')
# (';',)
# (';', 'and')
# ('and',)
# ('and', 'when')
# ('when',)
# ('when', 'alice')
# ('alice',)
# ('alice', 'had')
# ('had',)
# ('had', 'been')
# ('been',)
# ('been', 'all')
# ('all',)
# ('all', 'the')
# ('the',)
# ('the', 'way')
# ('way',)
# ('way', 'down')
# ('down',)
# ('down', 'one')
# ('one',)
# ('one', 'side')
# ('side',)
# ('side', 'and')
# ('and',)
# ('and', 'up')
# ('up',)
# ('up', 'the')
# ('the',)
# ('the', 'other')
# ('other',)
# ('other', ',')
# (',',)
# (',', 'trying')
# ('trying',)
# ('trying', 'every')
# ('every',)
# ('every', 'door')
# ('door',)
# ('door', ',')
# (',',)
# (',', 'she')
# ('she',)
# ('she', 'walked')
# ('walked',)
# ('walked', 'sadly')
# ('sadly',)
# ('sadly', 'down')
# ('down',)
# ('down', 'the')
# ('the',)
# ('the', 'middle')
# ('middle',)
# ('middle', ',')
# (',',)
# (',', 'wondering')
# ('wondering',)
# ('wondering', 'how')
# ('how',)
# ('how', 'she')
# ('she',)
# ('she', 'was')
# ('was',)
# ('was', 'ever')
# ('ever',)
# ('ever', 'to')
# ('to',)
# ('to', 'get')
# ('get',)
# ('get', 'out')
# ('out',)
# ('out', 'again')
# ('again',)
# ('again', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'suddenly')
# ('suddenly',)
# ('suddenly', 'she')
# ('she',)
# ('she', 'came')
# ('came',)
# ('came', 'upon')
# ('upon',)
# ('upon', 'a')
# ('a',)
# ('a', 'little')
# ('little',)
# ('little', 'three-legged')
# ('three-legged',)
# ('three-legged', 'table')
# ('table',)
# ('table', ',')
# (',',)
# (',', 'all')
# ('all',)
# ('all', 'made')
# ('made',)
# ('made', 'of')
# ('of',)
# ('of', 'solid')
# ('solid',)
# ('solid', 'glass')
# ('glass',)
# ('glass', ';')
# (';',)
# (';', 'there')
# ('there',)
# ('there', 'was')
# ('was',)
# ('was', 'nothing')
# ('nothing',)
# ('nothing', 'on')
# ('on',)
# ('on', 'it')
# ('it',)
# ('it', 'except')
# ('except',)
# ('except', 'a')
# ('a',)
# ('a', 'tiny')
# ('tiny',)
# ('tiny', 'golden')
# ('golden',)
# ('golden', 'key')
# ('key',)
# ('key', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', "alice's")
# ("alice's",)
# ("alice's", 'first')
# ('first',)
# ('first', 'thought')
# ('thought',)
# ('thought', 'was')
# ('was',)
# ('was', 'that')
# ('that',)
# ('that', 'it')
# ('it',)
# ('it', 'might')
# ('might',)
# ('might', 'belong')
# ('belong',)
# ('belong', 'to')
# ('to',)
# ('to', 'one')
# ('one',)
# ('one', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'doors')
# ('doors',)
# ('doors', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'hall')
# ('hall',)
# ('hall', ';')
# (';',)
# (';', 'but')
# ('but',)
# ('but', ',')
# (',',)
# (',', 'alas')
# ('alas',)
# ('alas', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'either')
# ('either',)
# ('either', 'the')
# ('the',)
# ('the', 'locks')
# ('locks',)
# ('locks', 'were')
# ('were',)
# ('were', 'too')
# ('too',)
# ('too', 'large')
# ('large',)
# ('large', ',')
# (',',)
# (',', 'or')
# ('or',)
# ('or', 'the')
# ('the',)
# ('the', 'key')
# ('key',)
# ('key', 'was')
# ('was',)
# ('was', 'too')
# ('too',)
# ('too', 'small')
# ('small',)
# ('small', ',')
# (',',)
# (',', 'but')
# ('but',)
# ('but', 'at')
# ('at',)
# ('at', 'any')
# ('any',)
# ('any', 'rate')
# ('rate',)
# ('rate', 'it')
# ('it',)
# ('it', 'would')
# ('would',)
# ('would', 'not')
# ('not',)
# ('not', 'open')
# ('open',)
# ('open', 'any')
# ('any',)
# ('any', 'of')
# ('of',)
# ('of', 'them')
# ('them',)
# ('them', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'however')
# ('however',)
# ('however', ',')
# (',',)
# (',', 'on')
# ('on',)
# ('on', 'the')
# ('the',)
# ('the', 'second')
# ('second',)
# ('second', 'time')
# ('time',)
# ('time', 'round')
# ('round',)
# ('round', ',')
# (',',)
# (',', 'she')
# ('she',)
# ('she', 'came')
# ('came',)
# ('came', 'upon')
# ('upon',)
# ('upon', 'a')
# ('a',)
# ('a', 'low')
# ('low',)
# ('low', 'curtain')
# ('curtain',)
# ('curtain', 'she')
# ('she',)
# ('she', 'had')
# ('had',)
# ('had', 'not')
# ('not',)
# ('not', 'noticed')
# ('noticed',)
# ('noticed', 'before')
# ('before',)
# ('before', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'behind')
# ('behind',)
# ('behind', 'it')
# ('it',)
# ('it', 'was')
# ('was',)
# ('was', 'a')
# ('a',)
# ('a', 'little')
# ('little',)
# ('little', 'door')
# ('door',)
# ('door', 'about')
# ('about',)
# ('about', 'fifteen')
# ('fifteen',)
# ('fifteen', 'inches')
# ('inches',)
# ('inches', 'high')
# ('high',)
# ('high', ':')
# (':',)
# (':', 'she')
# ('she',)
# ('she', 'tried')
# ('tried',)
# ('tried', 'the')
# ('the',)
# ('the', 'little')
# ('little',)
# ('little', 'golden')
# ('golden',)
# ('golden', 'key')
# ('key',)
# ('key', 'in')
# ('in',)
# ('in', 'the')
# ('the',)
# ('the', 'lock')
# ('lock',)
# ('lock', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'to')
# ('to',)
# ('to', 'her')
# ('her',)
# ('her', 'great')
# ('great',)
# ('great', 'delight')
# ('delight',)
# ('delight', 'it')
# ('it',)
# ('it', 'fitted')
# ('fitted',)
# ('fitted', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'alice')
# ('alice',)
# ('alice', 'opened')
# ('opened',)
# ('opened', 'the')
# ('the',)
# ('the', 'door')
# ('door',)
# ('door', 'and')
# ('and',)
# ('and', 'found')
# ('found',)
# ('found', 'that')
# ('that',)
# ('that', 'it')
# ('it',)
# ('it', 'led')
# ('led',)
# ('led', 'into')
# ('into',)
# ('into', 'a')
# ('a',)
# ('a', 'small')
# ('small',)
# ('small', 'passage')
# ('passage',)
# ('passage', ',')
# (',',)
# (',', 'not')
# ('not',)
# ('not', 'much')
# ('much',)
# ('much', 'larger')
# ('larger',)
# ('larger', 'than')
# ('than',)
# ('than', 'a')
# ('a',)
# ('a', 'rat-hole')
# ('rat-hole',)
# ('rat-hole', ':')
# (':',)
# (':', 'she')
# ('she',)
# ('she', 'knelt')
# ('knelt',)
# ('knelt', 'down')
# ('down',)
# ('down', 'and')
# ('and',)
# ('and', 'looked')
# ('looked',)
# ('looked', 'along')
# ('along',)
# ('along', 'the')
# ('the',)
# ('the', 'passage')
# ('passage',)
# ('passage', 'into')
# ('into',)
# ('into', 'the')
# ('the',)
# ('the', 'loveliest')
# ('loveliest',)
# ('loveliest', 'garden')
# ('garden',)
# ('garden', 'you')
# ('you',)
# ('you', 'ever')
# ('ever',)
# ('ever', 'saw')
# ('saw',)
# ('saw', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'how')
# ('how',)
# ('how', 'she')
# ('she',)
# ('she', 'longed')
# ('longed',)
# ('longed', 'to')
# ('to',)
# ('to', 'get')
# ('get',)
# ('get', 'out')
# ('out',)
# ('out', 'of')
# ('of',)
# ('of', 'that')
# ('that',)
# ('that', 'dark')
# ('dark',)
# ('dark', 'hall')
# ('hall',)
# ('hall', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'wander')
# ('wander',)
# ('wander', 'about')
# ('about',)
# ('about', 'among')
# ('among',)
# ('among', 'those')
# ('those',)
# ('those', 'beds')
# ('beds',)
# ('beds', 'of')
# ('of',)
# ('of', 'bright')
# ('bright',)
# ('bright', 'flowers')
# ('flowers',)
# ('flowers', 'and')
# ('and',)
# ('and', 'those')
# ('those',)
# ('those', 'cool')
# ('cool',)
# ('cool', 'fountains')
# ('fountains',)
# ('fountains', ',')
# (',',)
# (',', 'but')
# ('but',)
# ('but', 'she')
# ('she',)
# ('she', 'could')
# ('could',)
# ('could', 'not')
# ('not',)
# ('not', 'even')
# ('even',)
# ('even', 'get')
# ('get',)
# ('get', 'her')
# ('her',)
# ('her', 'head')
# ('head',)
# ('head', 'through')
# ('through',)
# ('through', 'the')
# ('the',)
# ('the', 'doorway')
# ('doorway',)
# ('doorway', ';')
# (';',)
# (';', "'")
# ("'",)
# ("'", 'and')
# ('and',)
# ('and', 'even')
# ('even',)
# ('even', 'if')
# ('if',)
# ('if', 'my')
# ('my',)
# ('my', 'head')
# ('head',)
# ('head', 'would')
# ('would',)
# ('would', 'go')
# ('go',)
# ('go', 'through')
# ('through',)
# ('through', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'thought')
# ('thought',)
# ('thought', 'poor')
# ('poor',)
# ('poor', 'alice')
# ('alice',)
# ('alice', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'it')
# ('it',)
# ('it', 'would')
# ('would',)
# ('would', 'be')
# ('be',)
# ('be', 'of')
# ('of',)
# ('of', 'very')
# ('very',)
# ('very', 'little')
# ('little',)
# ('little', 'use')
# ('use',)
# ('use', 'without')
# ('without',)
# ('without', 'my')
# ('my',)
# ('my', 'shoulders')
# ('shoulders',)
# ('shoulders', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'oh')
# ('oh',)
# ('oh', ',')
# (',',)
# (',', 'how')
# ('how',)
# ('how', 'i')
# ('i',)
# ('i', 'wish')
# ('wish',)
# ('wish', 'i')
# ('i',)
# ('i', 'could')
# ('could',)
# ('could', 'shut')
# ('shut',)
# ('shut', 'up')
# ('up',)
# ('up', 'like')
# ('like',)
# ('like', 'a')
# ('a',)
# ('a', 'telescope')
# ('telescope',)
# ('telescope', '!')
# ('!',)
# ('!', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'i')
# ('i',)
# ('i', 'think')
# ('think',)
# ('think', 'i')
# ('i',)
# ('i', 'could')
# ('could',)
# ('could', ',')
# (',',)
# (',', 'if')
# ('if',)
# ('if', 'i')
# ('i',)
# ('i', 'only')
# ('only',)
# ('only', 'know')
# ('know',)
# ('know', 'how')
# ('how',)
# ('how', 'to')
# ('to',)
# ('to', 'begin')
# ('begin',)
# ('begin', '.')
# ('.',)
# ('.', "'")
# ("'",)
# ("'", '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'for')
# ('for',)
# ('for', ',')
# (',',)
# (',', 'you')
# ('you',)
# ('you', 'see')
# ('see',)
# ('see', ',')
# (',',)
# (',', 'so')
# ('so',)
# ('so', 'many')
# ('many',)
# ('many', 'out-of-the-way')
# ('out-of-the-way',)
# ('out-of-the-way', 'things')
# ('things',)
# ('things', 'had')
# ('had',)
# ('had', 'happened')
# ('happened',)
# ('happened', 'lately')
# ('lately',)
# ('lately', ',')
# (',',)
# (',', 'that')
# ('that',)
# ('that', 'alice')
# ('alice',)
# ('alice', 'had')
# ('had',)
# ('had', 'begun')
# ('begun',)
# ('begun', 'to')
# ('to',)
# ('to', 'think')
# ('think',)
# ('think', 'that')
# ('that',)
# ('that', 'very')
# ('very',)
# ('very', 'few')
# ('few',)
# ('few', 'things')
# ('things',)
# ('things', 'indeed')
# ('indeed',)
# ('indeed', 'were')
# ('were',)
# ('were', 'really')
# ('really',)
# ('really', 'impossible')
# ('impossible',)
# ('impossible', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'there')
# ('there',)
# ('there', 'seemed')
# ('seemed',)
# ('seemed', 'to')
# ('to',)
# ('to', 'be')
# ('be',)
# ('be', 'no')
# ('no',)
# ('no', 'use')
# ('use',)
# ('use', 'in')
# ('in',)
# ('in', 'waiting')
# ('waiting',)
# ('waiting', 'by')
# ('by',)
# ('by', 'the')
# ('the',)
# ('the', 'little')
# ('little',)
# ('little', 'door')
# ('door',)
# ('door', ',')
# (',',)
# (',', 'so')
# ('so',)
# ('so', 'she')
# ('she',)
# ('she', 'went')
# ('went',)
# ('went', 'back')
# ('back',)
# ('back', 'to')
# ('to',)
# ('to', 'the')
# ('the',)
# ('the', 'table')
# ('table',)
# ('table', ',')
# (',',)
# (',', 'half')
# ('half',)
# ('half', 'hoping')
# ('hoping',)
# ('hoping', 'she')
# ('she',)
# ('she', 'might')
# ('might',)
# ('might', 'find')
# ('find',)
# ('find', 'another')
# ('another',)
# ('another', 'key')
# ('key',)
# ('key', 'on')
# ('on',)
# ('on', 'it')
# ('it',)
# ('it', ',')
# (',',)
# (',', 'or')
# ('or',)
# ('or', 'at')
# ('at',)
# ('at', 'any')
# ('any',)
# ('any', 'rate')
# ('rate',)
# ('rate', 'a')
# ('a',)
# ('a', 'book')
# ('book',)
# ('book', 'of')
# ('of',)
# ('of', 'rules')
# ('rules',)
# ('rules', 'for')
# ('for',)
# ('for', 'shutting')
# ('shutting',)
# ('shutting', 'people')
# ('people',)
# ('people', 'up')
# ('up',)
# ('up', 'like')
# ('like',)
# ('like', 'telescopes')
# ('telescopes',)
# ('telescopes', ':')
# (':',)
# (':', 'this')
# ('this',)
# ('this', 'time')
# ('time',)
# ('time', 'she')
# ('she',)
# ('she', 'found')
# ('found',)
# ('found', 'a')
# ('a',)
# ('a', 'little')
# ('little',)
# ('little', 'bottle')
# ('bottle',)
# ('bottle', 'on')
# ('on',)
# ('on', 'it')
# ('it',)
# ('it', ',')
# (',',)
# (',', '(')
# ('(',)
# ('(', "'")
# ("'",)
# ("'", 'which')
# ('which',)
# ('which', 'certainly')
# ('certainly',)
# ('certainly', 'was')
# ('was',)
# ('was', 'not')
# ('not',)
# ('not', 'here')
# ('here',)
# ('here', 'before')
# ('before',)
# ('before', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'said')
# ('said',)
# ('said', 'alice')
# ('alice',)
# ('alice', ',')
# (',',)
# (',', ')')
# (')',)
# (')', 'and')
# ('and',)
# ('and', 'round')
# ('round',)
# ('round', 'the')
# ('the',)
# ('the', 'neck')
# ('neck',)
# ('neck', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'bottle')
# ('bottle',)
# ('bottle', 'was')
# ('was',)
# ('was', 'a')
# ('a',)
# ('a', 'paper')
# ('paper',)
# ('paper', 'label')
# ('label',)
# ('label', ',')
# (',',)
# (',', 'with')
# ('with',)
# ('with', 'the')
# ('the',)
# ('the', 'words')
# ('words',)
# ('words', "'")
# ("'",)
# ("'", 'drink')
# ('drink',)
# ('drink', 'me')
# ('me',)
# ('me', "'")
# ("'",)
# ("'", 'beautifully')
# ('beautifully',)
# ('beautifully', 'printed')
# ('printed',)
# ('printed', 'on')
# ('on',)
# ('on', 'it')
# ('it',)
# ('it', 'in')
# ('in',)
# ('in', 'large')
# ('large',)
# ('large', 'letters')
# ('letters',)
# ('letters', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'it')
# ('it',)
# ('it', 'was')
# ('was',)
# ('was', 'all')
# ('all',)
# ('all', 'very')
# ('very',)
# ('very', 'well')
# ('well',)
# ('well', 'to')
# ('to',)
# ('to', 'say')
# ('say',)
# ('say', "'")
# ("'",)
# ("'", 'drink')
# ('drink',)
# ('drink', 'me')
# ('me',)
# ('me', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'but')
# ('but',)
# ('but', 'the')
# ('the',)
# ('the', 'wise')
# ('wise',)
# ('wise', 'little')
# ('little',)
# ('little', 'alice')
# ('alice',)
# ('alice', 'was')
# ('was',)
# ('was', 'not')
# ('not',)
# ('not', 'going')
# ('going',)
# ('going', 'to')
# ('to',)
# ('to', 'do')
# ('do',)
# ('do', 'that')
# ('that',)
# ('that', 'in')
# ('in',)
# ('in', 'a')
# ('a',)
# ('a', 'hurry')
# ('hurry',)
# ('hurry', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', "'")
# ("'",)
# ("'", 'no')
# ('no',)
# ('no', ',')
# (',',)
# (',', "i'll")
# ("i'll",)
# ("i'll", 'look')
# ('look',)
# ('look', 'first')
# ('first',)
# ('first', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'she')
# ('she',)
# ('she', 'said')
# ('said',)
# ('said', ',')
# (',',)
# (',', "'")
# ("'",)
# ("'", 'and')
# ('and',)
# ('and', 'see')
# ('see',)
# ('see', 'whether')
# ('whether',)
# ('whether', "it's")
# ("it's",)
# ("it's", 'marked')
# ('marked',)
# ('marked', '"')
# ('"',)
# ('"', 'poison')
# ('poison',)
# ('poison', '"')
# ('"',)
# ('"', 'or')
# ('or',)
# ('or', 'not')
# ('not',)
# ('not', "'")
# ("'",)
# ("'", ';')
# (';',)
# (';', 'for')
# ('for',)
# ('for', 'she')
# ('she',)
# ('she', 'had')
# ('had',)
# ('had', 'read')
# ('read',)
# ('read', 'several')
# ('several',)
# ('several', 'nice')
# ('nice',)
# ('nice', 'little')
# ('little',)
# ('little', 'histories')
# ('histories',)
# ('histories', 'about')
# ('about',)
# ('about', 'children')
# ('children',)
# ('children', 'who')
# ('who',)
# ...
# ('the',)
# ('the', 'tiny')
# ('tiny',)
# ('tiny', 'hands')
# ('hands',)
# ('hands', 'were')
# ('were',)
# ('were', 'clasped')
# ('clasped',)
# ('clasped', 'upon')
# ('upon',)
# ('upon', 'her')
# ('her',)
# ('her', 'knee')
# ('knee',)
# ('knee', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'the')
# ('the',)
# ('the', 'bright')
# ('bright',)
# ('bright', 'eager')
# ('eager',)
# ('eager', 'eyes')
# ('eyes',)
# ('eyes', 'were')
# ('were',)
# ('were', 'looking')
# ('looking',)
# ('looking', 'up')
# ('up',)
# ('up', 'into')
# ('into',)
# ('into', 'hers--she')
# ('hers--she',)
# ('hers--she', 'could')
# ('could',)
# ('could', 'hear')
# ('hear',)
# ('hear', 'the')
# ('the',)
# ('the', 'very')
# ('very',)
# ('very', 'tones')
# ('tones',)
# ('tones', 'of')
# ('of',)
# ('of', 'her')
# ('her',)
# ('her', 'voice')
# ('voice',)
# ('voice', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'see')
# ('see',)
# ('see', 'that')
# ('that',)
# ('that', 'queer')
# ('queer',)
# ('queer', 'little')
# ('little',)
# ('little', 'toss')
# ('toss',)
# ('toss', 'of')
# ('of',)
# ('of', 'her')
# ('her',)
# ('her', 'head')
# ('head',)
# ('head', 'to')
# ('to',)
# ('to', 'keep')
# ('keep',)
# ('keep', 'back')
# ('back',)
# ('back', 'the')
# ('the',)
# ('the', 'wandering')
# ('wandering',)
# ('wandering', 'hair')
# ('hair',)
# ('hair', 'that')
# ('that',)
# ('that', 'would')
# ('would',)
# ('would', 'always')
# ('always',)
# ('always', 'get')
# ('get',)
# ('get', 'into')
# ('into',)
# ('into', 'her')
# ('her',)
# ('her', 'eyes--and')
# ('eyes--and',)
# ('eyes--and', 'still')
# ('still',)
# ('still', 'as')
# ('as',)
# ('as', 'she')
# ('she',)
# ('she', 'listened')
# ('listened',)
# ('listened', ',')
# (',',)
# (',', 'or')
# ('or',)
# ('or', 'seemed')
# ('seemed',)
# ('seemed', 'to')
# ('to',)
# ('to', 'listen')
# ('listen',)
# ('listen', ',')
# (',',)
# (',', 'the')
# ('the',)
# ('the', 'whole')
# ('whole',)
# ('whole', 'place')
# ('place',)
# ('place', 'around')
# ('around',)
# ('around', 'her')
# ('her',)
# ('her', 'became')
# ('became',)
# ('became', 'alive')
# ('alive',)
# ('alive', 'the')
# ('the',)
# ('the', 'strange')
# ('strange',)
# ('strange', 'creatures')
# ('creatures',)
# ('creatures', 'of')
# ('of',)
# ('of', 'her')
# ('her',)
# ('her', 'little')
# ('little',)
# ('little', "sister's")
# ("sister's",)
# ("sister's", 'dream')
# ('dream',)
# ('dream', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'the')
# ('the',)
# ('the', 'long')
# ('long',)
# ('long', 'grass')
# ('grass',)
# ('grass', 'rustled')
# ('rustled',)
# ('rustled', 'at')
# ('at',)
# ('at', 'her')
# ('her',)
# ('her', 'feet')
# ('feet',)
# ('feet', 'as')
# ('as',)
# ('as', 'the')
# ('the',)
# ('the', 'white')
# ('white',)
# ('white', 'rabbit')
# ('rabbit',)
# ('rabbit', 'hurried')
# ('hurried',)
# ('hurried', 'by--the')
# ('by--the',)
# ('by--the', 'frightened')
# ('frightened',)
# ('frightened', 'mouse')
# ('mouse',)
# ('mouse', 'splashed')
# ('splashed',)
# ('splashed', 'his')
# ('his',)
# ('his', 'way')
# ('way',)
# ('way', 'through')
# ('through',)
# ('through', 'the')
# ('the',)
# ('the', 'neighbouring')
# ('neighbouring',)
# ('neighbouring', 'pool--she')
# ('pool--she',)
# ('pool--she', 'could')
# ('could',)
# ('could', 'hear')
# ('hear',)
# ('hear', 'the')
# ('the',)
# ('the', 'rattle')
# ('rattle',)
# ('rattle', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'teacups')
# ('teacups',)
# ('teacups', 'as')
# ('as',)
# ('as', 'the')
# ('the',)
# ('the', 'march')
# ('march',)
# ('march', 'hare')
# ('hare',)
# ('hare', 'and')
# ('and',)
# ('and', 'his')
# ('his',)
# ('his', 'friends')
# ('friends',)
# ('friends', 'shared')
# ('shared',)
# ('shared', 'their')
# ('their',)
# ('their', 'never-ending')
# ('never-ending',)
# ('never-ending', 'meal')
# ('meal',)
# ('meal', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'the')
# ('the',)
# ('the', 'shrill')
# ('shrill',)
# ('shrill', 'voice')
# ('voice',)
# ('voice', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'queen')
# ('queen',)
# ('queen', 'ordering')
# ('ordering',)
# ('ordering', 'off')
# ('off',)
# ('off', 'her')
# ('her',)
# ('her', 'unfortunate')
# ('unfortunate',)
# ('unfortunate', 'guests')
# ('guests',)
# ('guests', 'to')
# ('to',)
# ('to', 'execution--once')
# ('execution--once',)
# ('execution--once', 'more')
# ('more',)
# ('more', 'the')
# ('the',)
# ('the', 'pig-baby')
# ('pig-baby',)
# ('pig-baby', 'was')
# ('was',)
# ('was', 'sneezing')
# ('sneezing',)
# ('sneezing', 'on')
# ('on',)
# ('on', 'the')
# ('the',)
# ('the', "duchess's")
# ("duchess's",)
# ("duchess's", 'knee')
# ('knee',)
# ('knee', ',')
# (',',)
# (',', 'while')
# ('while',)
# ('while', 'plates')
# ('plates',)
# ('plates', 'and')
# ('and',)
# ('and', 'dishes')
# ('dishes',)
# ('dishes', 'crashed')
# ('crashed',)
# ('crashed', 'around')
# ('around',)
# ('around', 'it--once')
# ('it--once',)
# ('it--once', 'more')
# ('more',)
# ('more', 'the')
# ('the',)
# ('the', 'shriek')
# ('shriek',)
# ('shriek', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'gryphon')
# ('gryphon',)
# ('gryphon', ',')
# (',',)
# (',', 'the')
# ('the',)
# ('the', 'squeaking')
# ('squeaking',)
# ('squeaking', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', "lizard's")
# ("lizard's",)
# ("lizard's", 'slate-pencil')
# ('slate-pencil',)
# ('slate-pencil', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'the')
# ('the',)
# ('the', 'choking')
# ('choking',)
# ('choking', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'suppressed')
# ('suppressed',)
# ('suppressed', 'guinea-pigs')
# ('guinea-pigs',)
# ('guinea-pigs', ',')
# (',',)
# (',', 'filled')
# ('filled',)
# ('filled', 'the')
# ('the',)
# ('the', 'air')
# ('air',)
# ('air', ',')
# (',',)
# (',', 'mixed')
# ('mixed',)
# ('mixed', 'up')
# ('up',)
# ('up', 'with')
# ('with',)
# ('with', 'the')
# ('the',)
# ('the', 'distant')
# ('distant',)
# ('distant', 'sobs')
# ('sobs',)
# ('sobs', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'miserable')
# ('miserable',)
# ('miserable', 'mock')
# ('mock',)
# ('mock', 'turtle')
# ('turtle',)
# ('turtle', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'so')
# ('so',)
# ('so', 'she')
# ('she',)
# ('she', 'sat')
# ('sat',)
# ('sat', 'on')
# ('on',)
# ('on', ',')
# (',',)
# (',', 'with')
# ('with',)
# ('with', 'closed')
# ('closed',)
# ('closed', 'eyes')
# ('eyes',)
# ('eyes', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'half')
# ('half',)
# ('half', 'believed')
# ('believed',)
# ('believed', 'herself')
# ('herself',)
# ('herself', 'in')
# ('in',)
# ('in', 'wonderland')
# ('wonderland',)
# ('wonderland', ',')
# (',',)
# (',', 'though')
# ('though',)
# ('though', 'she')
# ('she',)
# ('she', 'knew')
# ('knew',)
# ('knew', 'she')
# ('she',)
# ('she', 'had')
# ('had',)
# ('had', 'but')
# ('but',)
# ('but', 'to')
# ('to',)
# ('to', 'open')
# ('open',)
# ('open', 'them')
# ('them',)
# ('them', 'again')
# ('again',)
# ('again', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'all')
# ('all',)
# ('all', 'would')
# ('would',)
# ('would', 'change')
# ('change',)
# ('change', 'to')
# ('to',)
# ('to', 'dull')
# ('dull',)
# ('dull', 'reality--the')
# ('reality--the',)
# ('reality--the', 'grass')
# ('grass',)
# ('grass', 'would')
# ('would',)
# ('would', 'be')
# ('be',)
# ('be', 'only')
# ('only',)
# ('only', 'rustling')
# ('rustling',)
# ('rustling', 'in')
# ('in',)
# ('in', 'the')
# ('the',)
# ('the', 'wind')
# ('wind',)
# ('wind', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'the')
# ('the',)
# ('the', 'pool')
# ('pool',)
# ('pool', 'rippling')
# ('rippling',)
# ('rippling', 'to')
# ('to',)
# ('to', 'the')
# ('the',)
# ('the', 'waving')
# ('waving',)
# ('waving', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'reeds--the')
# ('reeds--the',)
# ('reeds--the', 'rattling')
# ('rattling',)
# ('rattling', 'teacups')
# ('teacups',)
# ('teacups', 'would')
# ('would',)
# ('would', 'change')
# ('change',)
# ('change', 'to')
# ('to',)
# ('to', 'tinkling')
# ('tinkling',)
# ('tinkling', 'sheep-bells')
# ('sheep-bells',)
# ('sheep-bells', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'the')
# ('the',)
# ('the', "queen's")
# ("queen's",)
# ("queen's", 'shrill')
# ('shrill',)
# ('shrill', 'cries')
# ('cries',)
# ('cries', 'to')
# ('to',)
# ('to', 'the')
# ('the',)
# ('the', 'voice')
# ('voice',)
# ('voice', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'shepherd')
# ('shepherd',)
# ('shepherd', 'boy--and')
# ('boy--and',)
# ('boy--and', 'the')
# ('the',)
# ('the', 'sneeze')
# ('sneeze',)
# ('sneeze', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'baby')
# ('baby',)
# ('baby', ',')
# (',',)
# (',', 'the')
# ('the',)
# ('the', 'shriek')
# ('shriek',)
# ('shriek', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'gryphon')
# ('gryphon',)
# ('gryphon', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'all')
# ('all',)
# ('all', 'the')
# ('the',)
# ('the', 'other')
# ('other',)
# ('other', 'queer')
# ('queer',)
# ('queer', 'noises')
# ('noises',)
# ('noises', ',')
# (',',)
# (',', 'would')
# ('would',)
# ('would', 'change')
# ('change',)
# ('change', '(')
# ('(',)
# ('(', 'she')
# ('she',)
# ('she', 'knew')
# ('knew',)
# ('knew', ')')
# (')',)
# (')', 'to')
# ('to',)
# ('to', 'the')
# ('the',)
# ('the', 'confused')
# ('confused',)
# ('confused', 'clamour')
# ('clamour',)
# ('clamour', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'busy')
# ('busy',)
# ('busy', 'farm-yard--while')
# ('farm-yard--while',)
# ('farm-yard--while', 'the')
# ('the',)
# ('the', 'lowing')
# ('lowing',)
# ('lowing', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'cattle')
# ('cattle',)
# ('cattle', 'in')
# ('in',)
# ('in', 'the')
# ('the',)
# ('the', 'distance')
# ('distance',)
# ('distance', 'would')
# ('would',)
# ('would', 'take')
# ('take',)
# ('take', 'the')
# ('the',)
# ('the', 'place')
# ('place',)
# ('place', 'of')
# ('of',)
# ('of', 'the')
# ('the',)
# ('the', 'mock')
# ('mock',)
# ('mock', "turtle's")
# ("turtle's",)
# ("turtle's", 'heavy')
# ('heavy',)
# ('heavy', 'sobs')
# ('sobs',)
# ('sobs', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# ('<s>',)
# ('<s>', 'lastly')
# ('lastly',)
# ('lastly', ',')
# (',',)
# (',', 'she')
# ('she',)
# ('she', 'pictured')
# ('pictured',)
# ('pictured', 'to')
# ('to',)
# ('to', 'herself')
# ('herself',)
# ('herself', 'how')
# ('how',)
# ('how', 'this')
# ('this',)
# ('this', 'same')
# ('same',)
# ('same', 'little')
# ('little',)
# ('little', 'sister')
# ('sister',)
# ('sister', 'of')
# ('of',)
# ('of', 'hers')
# ('hers',)
# ('hers', 'would')
# ('would',)
# ('would', ',')
# (',',)
# (',', 'in')
# ('in',)
# ('in', 'the')
# ('the',)
# ('the', 'after-time')
# ('after-time',)
# ('after-time', ',')
# (',',)
# (',', 'be')
# ('be',)
# ('be', 'herself')
# ('herself',)
# ('herself', 'a')
# ('a',)
# ('a', 'grown')
# ('grown',)
# ('grown', 'woman')
# ('woman',)
# ('woman', ';')
# (';',)
# (';', 'and')
# ('and',)
# ('and', 'how')
# ('how',)
# ('how', 'she')
# ('she',)
# ('she', 'would')
# ('would',)
# ('would', 'keep')
# ('keep',)
# ('keep', ',')
# (',',)
# (',', 'through')
# ('through',)
# ('through', 'all')
# ('all',)
# ('all', 'her')
# ('her',)
# ('her', 'riper')
# ('riper',)
# ('riper', 'years')
# ('years',)
# ('years', ',')
# (',',)
# (',', 'the')
# ('the',)
# ('the', 'simple')
# ('simple',)
# ('simple', 'and')
# ('and',)
# ('and', 'loving')
# ('loving',)
# ('loving', 'heart')
# ('heart',)
# ('heart', 'of')
# ('of',)
# ('of', 'her')
# ('her',)
# ('her', 'childhood')
# ('childhood',)
# ('childhood', ':')
# (':',)
# (':', 'and')
# ('and',)
# ('and', 'how')
# ('how',)
# ('how', 'she')
# ('she',)
# ('she', 'would')
# ('would',)
# ('would', 'gather')
# ('gather',)
# ('gather', 'about')
# ('about',)
# ('about', 'her')
# ('her',)
# ('her', 'other')
# ('other',)
# ('other', 'little')
# ('little',)
# ('little', 'children')
# ('children',)
# ('children', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'make')
# ('make',)
# ('make', 'their')
# ('their',)
# ('their', 'eyes')
# ('eyes',)
# ('eyes', 'bright')
# ('bright',)
# ('bright', 'and')
# ('and',)
# ('and', 'eager')
# ('eager',)
# ('eager', 'with')
# ('with',)
# ('with', 'many')
# ('many',)
# ('many', 'a')
# ('a',)
# ('a', 'strange')
# ('strange',)
# ('strange', 'tale')
# ('tale',)
# ('tale', ',')
# (',',)
# (',', 'perhaps')
# ('perhaps',)
# ('perhaps', 'even')
# ('even',)
# ('even', 'with')
# ('with',)
# ('with', 'the')
# ('the',)
# ('the', 'dream')
# ('dream',)
# ('dream', 'of')
# ('of',)
# ('of', 'wonderland')
# ('wonderland',)
# ('wonderland', 'of')
# ('of',)
# ('of', 'long')
# ('long',)
# ('long', 'ago')
# ('ago',)
# ('ago', ':')
# (':',)
# (':', 'and')
# ('and',)
# ('and', 'how')
# ('how',)
# ('how', 'she')
# ('she',)
# ('she', 'would')
# ('would',)
# ('would', 'feel')
# ('feel',)
# ('feel', 'with')
# ('with',)
# ('with', 'all')
# ('all',)
# ('all', 'their')
# ('their',)
# ('their', 'simple')
# ('simple',)
# ('simple', 'sorrows')
# ('sorrows',)
# ('sorrows', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'find')
# ('find',)
# ('find', 'a')
# ('a',)
# ('a', 'pleasure')
# ('pleasure',)
# ('pleasure', 'in')
# ('in',)
# ('in', 'all')
# ('all',)
# ('all', 'their')
# ('their',)
# ('their', 'simple')
# ('simple',)
# ('simple', 'joys')
# ('joys',)
# ('joys', ',')
# (',',)
# (',', 'remembering')
# ('remembering',)
# ('remembering', 'her')
# ('her',)
# ('her', 'own')
# ('own',)
# ('own', 'child-life')
# ('child-life',)
# ('child-life', ',')
# (',',)
# (',', 'and')
# ('and',)
# ('and', 'the')
# ('the',)
# ('the', 'happy')
# ('happy',)
# ('happy', 'summer')
# ('summer',)
# ('summer', 'days')
# ('days',)
# ('days', '.')
# ('.',)
# ('.', '</s>')
# ('</s>',)
# Vocabulary words:  ['<s>', '[', "alice's", 'adventures', 'in', 'wonderland', 'by', 'lewis', 'carroll', '1865', ']', 'chapter', 'i', '.', 'down', 'the', 'rabbit-hole', 'alice', 'was', 'beginning', 'to', 'get', 'very', 'tired', 'of', 'sitting', 'by', 'her', 'sister', 'on', 'the', 'bank', ',', 'and', 'of', 'having', 'nothing', 'to', 'do:', 'once', 'or', 'twice', 'she', 'had', 'peeped', 'into', 'the', 'book', 'her', 'sister', 'was', 'reading', ',', 'but', 'it', 'had', 'no', 'pictures', 'or', 'conversations', 'in', 'it', ',', "'", 'and', 'what', 'is', 'the', 'use', 'of', 'a', 'book', ',', "'", 'thought', 'alice', "'", 'without', 'pictures', 'or', 'conversation', '?', "'", '</s>', '<s>', 'so', 'she', 'was', 'considering', 'in', 'her', 'own', 'mind', '(', 'as', 'well', 'as', 'she', 'could', ',', 'for', 'the', 'hot', 'day', 'made', 'her', 'feel', 'very', 'sleepy', 'and', 'stupid', ')', ',', 'whether', 'the', 'pleasure', 'of', 'making', 'a', 'daisy-chain', 'would', 'be', 'worth', 'the', 'trouble', 'of', 'getting', 'up', 'and', 'picking', 'the', 'daisies', ',', 'when', 'suddenly', 'a', 'white', 'rabbit', 'with', 'pink', 'eyes', 'ran', 'close', 'by', 'her', '.', '</s>', '<s>', 'there', 'was', 'nothing', 'so', 'very', 'remarkable', 'in', 'that', ';', 'nor', 'did', 'alice', 'think', 'it', 'so', 'very', 'much', 'out', 'of', 'the', 'way', 'to', 'hear', 'the', 'rabbit', 'say', 'to', 'itself', ',', "'", 'oh', 'dear', '!', '</s>', '<s>', 'oh', 'dear', '!', '</s>', '<s>', 'i', 'shall', 'be', 'late', '!', "'", '</s>', '<s>', '(', 'when', 'she', 'thought', 'it', 'over', 'afterwards', ',', 'it', 'occurred', 'to', 'her', 'that', 'she', 'ought', 'to', 'have', 'wondered', 'at', 'this', ',', 'but', 'at', 'the', 'time', 'it', 'all', 'seemed', 'quite', 'natural', ');', 'but', 'when', 'the', 'rabbit', 'actually', 'took', 'a', 'watch', 'out', 'of', 'its', 'waistcoat-pocket', ',', 'and', 'looked', 'at', 'it', ',', 'and', 'then', 'hurried', 'on', ',', 'alice', 'started', 'to', 'her', 'feet', ',', 'for', 'it', 'flashed', 'across', 'her', 'mind', 'that', 'she', 'had', 'never', 'before', 'seen', 'a', 'rabbit', 'with', 'either', 'a', 'waistcoat-pocket', ',', 'or', 'a', 'watch', 'to', 'take', 'out', 'of', 'it', ',', 'and', 'burning', 'with', 'curiosity', ',', 'she', 'ran', 'across', 'the', 'field', 'after', 'it', ',', 'and', 'fortunately', 'was', 'just', 'in', 'time', 'to', 'see', 'it', 'pop', 'down', 'a', 'large', 'rabbit-hole', 'under', 'the', 'hedge', '.', '</s>', '<s>', 'in', 'another', 'moment', 'down', 'went', 'alice', 'after', 'it', ',', 'never', 'once', 'considering', 'how', 'in', 'the', 'world', 'she', 'was', 'to', 'get', 'out', 'again', '.', '</s>', '<s>', 'the', 'rabbit-hole', 'went', 'straight', 'on', 'like', 'a', 'tunnel', 'for', 'some', 'way', ',', 'and', 'then', 'dipped', 'suddenly', 'down', ',', 'so', 'suddenly', 'that', 'alice', 'had', 'not', 'a', 'moment', 'to', 'think', 'about', 'stopping', 'herself', 'before', 'she', 'found', 'herself', 'falling', 'down', 'a', 'very', 'deep', 'well', '.', '</s>', '<s>', 'either', 'the', 'well', 'was', 'very', 'deep', ',', 'or', 'she', 'fell', 'very', 'slowly', ',', 'for', 'she', 'had', 'plenty', 'of', 'time', 'as', 'she', 'went', 'down', 'to', 'look', 'about', 'her', 'and', 'to', 'wonder', 'what', 'was', 'going', 'to', 'happen', 'next', '.', '</s>', '<s>', 'first', ',', 'she', 'tried', 'to', 'look', 'down', 'and', 'make', 'out', 'what', 'she', 'was', 'coming', 'to', ',', 'but', 'it', 'was', 'too', 'dark', 'to', 'see', 'anything', ';', 'then', 'she', 'looked', 'at', 'the', 'sides', 'of', 'the', 'well', ',', 'and', 'noticed', 'that', 'they', 'were', 'filled', 'with', 'cupboards', 'and', 'book-shelves', ';', 'here', 'and', 'there', 'she', 'saw', 'maps', 'and', 'pictures', 'hung', 'upon', 'pegs', '.', '</s>', '<s>', 'she', 'took', 'down', 'a', 'jar', 'from', 'one', 'of', 'the', 'shelves', 'as', 'she', 'passed', ';', 'it', 'was', 'labelled', "'", 'orange', 'marmalade', "'", ',', 'but', 'to', 'her', 'great', 'disapp ...
# Vocabulary length:  36899

# %% [markdown]
# #### Create the vocabulary
#
# https://www.nltk.org/api/nltk.lm.vocabulary.html
#
# We need to create an object of the class `Vocabulary` that will contain the vocabulary of valid words.
# We can filter the less frequent words using the parameter `unk_cutoff`. All words with a frequency lower than this parameter will be removed from the vocabulary and will considered as unknown (`UNK`).

# %%
from nltk.lm.vocabulary import Vocabulary

vocabulary_train = Vocabulary(vocab_list, unk_cutoff=1)

# Prints the vocabulary
for word in vocabulary_train:
    print(word)
# Out:
# <s>
# [
# alice's
# adventures
# in
# wonderland
# by
# lewis
# carroll
# 1865
# ]
# chapter
# i
# .
# down
# the
# rabbit-hole
# alice
# was
# beginning
# to
# get
# very
# tired
# of
# sitting
# her
# sister
# on
# bank
# ,
# and
# having
# nothing
# do:
# once
# or
# twice
# she
# had
# peeped
# into
# book
# reading
# but
# it
# no
# pictures
# conversations
# '
# what
# is
# use
# a
# thought
# without
# conversation
# ?
# </s>
# so
# considering
# own
# mind
# (
# as
# well
# could
# for
# hot
# day
# made
# feel
# sleepy
# stupid
# )
# whether
# pleasure
# making
# daisy-chain
# would
# be
# worth
# trouble
# getting
# up
# picking
# daisies
# when
# suddenly
# white
# rabbit
# with
# pink
# eyes
# ran
# close
# there
# remarkable
# that
# ;
# nor
# did
# think
# much
# out
# way
# hear
# say
# itself
# oh
# dear
# !
# shall
# late
# over
# afterwards
# occurred
# ought
# have
# wondered
# at
# this
# time
# all
# seemed
# quite
# natural
# );
# actually
# took
# watch
# its
# waistcoat-pocket
# looked
# then
# hurried
# started
# feet
# flashed
# across
# never
# before
# seen
# either
# take
# burning
# curiosity
# field
# after
# fortunately
# just
# see
# pop
# large
# under
# hedge
# another
# moment
# went
# how
# world
# again
# straight
# like
# tunnel
# some
# dipped
# not
# about
# stopping
# herself
# found
# falling
# deep
# fell
# slowly
# plenty
# look
# wonder
# going
# happen
# next
# first
# tried
# make
# coming
# too
# dark
# anything
# sides
# noticed
# they
# were
# filled
# cupboards
# book-shelves
# here
# saw
# maps
# hung
# upon
# pegs
# jar
# from
# one
# shelves
# passed
# labelled
# orange
# marmalade
# great
# disappointment
# empty
# :
# drop
# fear
# killing
# somebody
# managed
# put
# past
# such
# fall
# tumbling
# stairs
# brave
# they'll
# me
# home
# why
# wouldn't
# even
# if
# off
# top
# house
# which
# likely
# true
# come
# an
# end
# many
# miles
# i've
# fallen
# said
# aloud
# must
# somewhere
# near
# centre
# earth
# let
# four
# thousand
# -
# you
# learnt
# several
# things
# sort
# lessons
# schoolroom
# though
# good
# opportunity
# showing
# knowledge
# listen
# still
# practice
# yes
# that's
# right
# distance--but
# latitude
# longitude
# got
# idea
# nice
# grand
# words
# presently
# began
# through
# funny
# it'll
# seem
# among
# people
# walk
# their
# heads
# downward
# antipathies
# rather
# glad
# listening
# didn't
# sound
# word
# ask
# them
# name
# country
# know
# please
# ma'am
# new
# zealand
# australia
# curtsey
# spoke--fancy
# curtseying
# you're
# air
# do
# manage
# ignorant
# little
# girl
# she'll
# asking
# perhaps
# written
# else
# soon
# talking
# dinah'll
# miss
# to-night
# should
# dinah
# cat
# hope
# remember
# saucer
# milk
# tea-time
# my
# wish
# are
# mice
# i'm
# afraid
# might
# catch
# bat
# mouse
# cats
# eat
# bats
# saying
# dreamy
# sometimes
# couldn't
# answer
# question
# matter
# felt
# dozing
# begun
# dream
# walking
# hand
# earnestly
# now
# tell
# truth
# ever
# thump
# came
# heap
# sticks
# dry
# leaves
# bit
# hurt
# jumped
# overhead
# long
# passage
# sight
# hurrying
# lost
# away
# wind
# turned
# corner
# ears
# whiskers
# it's
# behind
# longer
# low
# hall
# lit
# row
# lamps
# hanging
# roof
# doors
# round
# locked
# been
# side
# other
# trying
# every
# door
# walked
# sadly
# middle
# wondering
# three-legged
# table
# solid
# glass
# except
# tiny
# golden
# key
# belong
# alas
# locks
# small
# any
# rate
# open
# however
# second
# curtain
# fifteen
# inches
# high
# lock
# delight
# fitted
# opened
# led
# larger
# than
# rat-hole
# knelt
# along
# loveliest
# garden
# longed
# wander
# those
# beds
# bright
# flowers
# cool
# fountains
# head
# doorway
# go
# poor
# shoulders
# shut
# telescope
# only
# begin
# out-of-the-way
# happened
# lately
# few
# indeed
# really
# impossible
# waiting
# back
# half
# hoping
# find
# rules
# shutting
# telescopes
# bottle
# certainly
# neck
# paper
# label
# drink
# beautifully
# printed
# letters
# wise
# hurry
# i'll
# marked
# "
# poison
# read
# histories
# children
# who
# burnt
# eaten
# wild
# beasts
# unpleasant
# because
# simple
# friends
# taught
# red-hot
# poker
# will
# burn
# hold
# cut
# your
# finger
# deeply
# knife
# usually
# bleeds
# forgotten
# almost
# certain
# disagree
# sooner
# later
# ventured
# taste
# finding
# fact
# mixed
# flavour
# cherry-tart
# custard
# pine-apple
# roast
# turkey
# toffee
# buttered
# toast
# finished
# *
# curious
# feeling
# ten
# face
# brightened
# size
# lovely
# waited
# minutes
# shrink
# further
# nervous
# altogether
# candle
# fancy
# flame
# blown
# thing
# while
# more
# decided
# possibly
# reach
# plainly
# best
# climb
# legs
# slippery
# sat
# cried
# there's
# crying
# sharply
# advise
# leave
# minute
# generally
# gave
# advice
# seldom
# followed
# scolded
# severely
# bring
# tears
# remembered
# box
# cheated
# game
# croquet
# playing
# against
# child
# fond
# pretending
# two
# pretend
# hardly
# enough
# left
# respectable
# person
# eye
# lying
# cake
# currants
# makes
# grow
# can
# smaller
# creep
# don't
# care
# happens
# ate
# anxiously
# holding
# growing
# surprised
# remained
# same
# sure
# eats
# expecting
# dull
# life
# common
# set
# work
# ii
# pool
# curiouser
# forgot
# speak
# english
# opening
# largest
# good-bye
# far
# shoes
# stockings
# dears
# _i_
# shan't
# able
# deal
# myself
# kind
# won't
# want
# give
# pair
# boots
# christmas
# planning
# carrier
# sending
# presents
# one's
# odd
# directions
# foot
# esq
# hearthrug
# fender
# love
# nonsense
# struck
# nine
# hopeless
# cry
# ashamed
# yourself
# stop
# shedding
# gallons
# until
# reaching
# heard
# pattering
# distance
# hastily
# dried
# returning
# splendidly
# dressed
# kid
# gloves
# fan
# he
# trotting
# muttering
# himself
# duchess
# savage
# kept
# desperate
# ready
# help
# timid
# voice
# sir
# violently
# dropped
# skurried
# darkness
# hard
# fanning
# queer
# everything
# to-day
# yesterday
# usual
# changed
# night
# morning
# different
# am
# ah
# puzzle
# thinking
# knew
# age
# ada
# hair
# goes
# ringlets
# mine
# doesn't
# can't
# mabel
# sorts
# knows
# besides
# she's
# and--oh
# puzzling
# try
# used
# times
# five
# twelve
# six
# thirteen
# seven
# is--oh
# twenty
# multiplication
# signify
# let's
# geography
# london
# capital
# paris
# rome
# rome--no
# wrong
# doth
# crossed
# hands
# lap
# repeat
# sounded
# hoarse
# strange
# crocodile
# improve
# his
# shining
# tail
# pour
# waters
# nile
# scale
# cheerfully
# seems
# grin
# neatly
# spread
# claws
# welcome
# fishes
# gently
# smiling
# jaws
# live
# poky
# toys
# play
# learn
# stay
# putting
# being
# till
# sudden
# burst
# alone
# rabbit's
# done
# measure
# nearly
# guess
# shrinking
# rapidly
# cause
# avoid
# narrow
# escape
# frightened
# change
# existence
# speed
# worse
# declare
# bad
# these
# slipped
# splash
# chin
# salt
# water
# somehow
# sea
# case
# railway
# seaside
# general
# conclusion
# wherever
# coast
# number
# bathing
# machines
# digging
# sand
# wooden
# spades
# lodging
# houses
# station
# wept
# hadn't
# swam
# punished
# suppose
# drowned
# something
# splashing
# nearer
# walrus
# hippopotamus
# talk
# harm
# o
# swimming
# speaking
# brother's
# latin
# grammar
# mouse--of
# mouse--to
# mouse--a
# mouse--o
# inquisitively
# wink
# understand
# daresay
# french
# william
# conqueror
# history
# clear
# notion
# ago
# ou
# est
# ma
# chatte
# sentence
# lesson-book
# leap
# quiver
# fright
# beg
# pardon
# animal's
# feelings
# shrill
# passionate
# soothing
# tone
# angry
# yet
# show
# our
# you'd
# quiet
# lazily
# sits
# purring
# nicely
# fire
# licking
# paws
# washing
# face--and
# soft
# nurse--and
# catching
# mice--oh
# bristling
# offended
# we
# trembling
# subject
# family
# always
# hated
# nasty
# vulgar
# you--are
# fond--of--of
# dogs
# eagerly
# dog
# bright-eyed
# terrier
# curly
# brown
# fetch
# throw
# sit
# dinner
# things--i
# them--and
# belongs
# farmer
# says
# useful
# hundred
# pounds
# kills
# rats
# sorrowful
# commotion
# called
# softly
# pale
# passion
# us
# shore
# you'll
# hate
# crowded
# birds
# animals
# duck
# dodo
# lory
# eaglet
# creatures
# whole
# party
# iii
# caucus-race
# tale
# queer-looking
# assembled
# bank--the
# draggled
# feathers
# fur
# clinging
# dripping
# wet
# cross
# uncomfortable
# course
# consultation
# familiarly
# known
# argument
# last
# sulky
# older
# better
# allow
# knowing
# old
# positively
# refused
# authority
# ring
# fixed
# cold
# ahem
# important
# driest
# silence
# whose
# favoured
# pope
# submitted
# wanted
# leaders
# accustomed
# usurpation
# conquest
# edwin
# morcar
# earls
# mercia
# northumbria
# ugh
# shiver
# frowning
# politely
# proceed
# declared
# him
# stigand
# patriotic
# archbishop
# canterbury
# advisable
# replied
# crossly
# means
# frog
# worm
# notice
# hurriedly
# edgar
# atheling
# meet
# offer
# crown
# william's
# conduct
# moderate
# insolence
# normans
# continued
# turning
# spoke
# melancholy
# solemnly
# rising
# move
# meeting
# adjourn
# immediate
# adoption
# energetic
# remedies
# meaning
# what's
# believe
# bent
# hide
# smile
# tittered
# audibly
# paused
# inclined
# explain
# winter
# race-course
# circle
# exact
# shape
# placed
# three
# running
# liked
# easy
# race
# hour
# panting
# has
# won
# pressed
# forehead
# position
# shakespeare
# rest
# everybody
# prizes
# chorus
# voices
# asked
# pointing
# calling
# confused
# despair
# pocket
# pulled
# comfits
# luckily
# handed
# exactly
# a-piece
# prize
# gravely
# thimble
# presented
# acceptance
# elegant
# short
# speech
# cheered
# absurd
# grave
# dare
# laugh
# simply
# bowed
# looking
# solemn
# caused
# noise
# confusion
# complained
# theirs
# ones
# choked
# patted
# begged
# promised
# hate--c
# d
# added
# whisper
# sad
# sighing
# mouse's
# call
# fury
# met
# both
# law
# prosecute
# denial
# trial
# cur
# jury
# judge
# wasting
# breath
# cunning
# condemn
# death
# attending
# humbly
# fifth
# bend
# angrily
# knot
# undo
# insult
# mean
# pleaded
# easily
# growled
# reply
# finish
# story
# others
# joined
# shook
# impatiently
# quicker
# pity
# sighed
# crab
# daughter
# lesson
# lose
# temper
# tongue
# young
# snappishly
# patience
# oyster
# addressing
# nobody
# particular
# she'd
# venture
# pet
# dinah's
# bird
# sensation
# magpie
# wrapping
# carefully
# remarking
# night-air
# suit
# throat
# canary
# bed
# various
# pretexts
# moved
# mentioned
# lonely
# low-spirited
# footsteps
# iv
# sends
# bill
# executed
# ferrets
# where
# guessed
# good-naturedly
# hunting
# nowhere
# seen--everything
# since
# swim
# vanished
# completely
# mary
# ann
# doing
# run
# quick
# direction
# pointed
# mistake
# housemaid
# he'll
# finds
# i'd
# gloves--that
# neat
# brass
# plate
# w
# engraved
# knocking
# upstairs
# lest
# real
# messages
# fancying
# directly
# nurse
# they'd
# ordering
# tidy
# room
# window
# hoped
# pairs
# stood
# looking-glass
# nevertheless
# uncorked
# lips
# interesting
# whenever
# does
# expected
# drunk
# pressing
# ceiling
# stoop
# save
# broken
# enough--i
# more--as
# door--i
# kneel
# floor
# effect
# elbow
# arm
# curled
# resource
# chimney
# whatever
# become
# magic
# full
# grew
# chance
# unhappy
# pleasanter
# wasn't
# ordered
# rabbits
# gone
# rabbit-hole--and
# yet--and
# yet--it's
# fairy-tales
# fancied
# write
# one--but
# grown
# least
# that'll
# comfort
# way--never
# woman--but
# then--always
# shouldn't
# foolish
# answered
# lesson-books
# taking
# outside
# stopped
# trembled
# forgetting
# reason
# inwards
# attempt
# proved
# failure
# snatch
# shriek
# crash
# concluded
# possible
# cucumber-frame
# voice--the
# rabbit's--'pat
# pat
# apples
# yer
# honour
# sounds
# pronounced
# arrum
# goose
# fills
# business
# whispers
# coward
# shrieks
# cucumber-frames
# pulling
# hearing
# rumbling
# cartwheels
# together
# where's
# ladder
# bill's
# other--bill
# lad
# em
# corner--no
# tie
# first--they
# yet--oh
# particular--here
# rope--will
# bear
# loose
# slate--oh
# below
# loud
# fancy--who's
# nay
# down--here
# master
# shy
# place
# fireplace
# kick
# drew
# animal
# scratching
# scrambling
# above
# sharp
# along--'catch
# voices--'hold
# head--brandy
# now--don't
# choke
# him--how
# fellow
# feeble
# squeaking
# know--no
# thank
# ye
# now--but
# flustered
# you--all
# comes
# jack-in-the-box
# sky-rocket
# dead
# instantly
# sense
# moving
# barrowful
# doubt
# shower
# pebbles
# rattling
# hit
# shouted
# produced
# surprise
# cakes
# lay
# swallowed
# delighted
# crowd
# lizard
# held
# guinea-pigs
# giving
# rush
# appeared
# safe
# thick
# wood
# wandered
# plan
# excellent
# arranged
# difficulty
# smallest
# peering
# trees
# bark
# enormous
# puppy
# feebly
# stretching
# paw
# touch
# coaxing
# whistle
# terribly
# hungry
# spite
# picked
# stick
# whereupon
# yelp
# rushed
# worry
# dodged
# thistle
# keep
# tumbled
# heels
# cart-horse
# trampled
# series
# charges
# forwards
# each
# barking
# hoarsely
# mouth
# puppy's
# faint
# leant
# buttercup
# fanned
# teaching
# tricks
# if--if
# see--how
# blades
# grass
# circumstances
# mushroom
# height
# stretched
# tiptoe
# edge
# immediately
# caterpillar
# arms
# folded
# quietly
# smoking
# hookah
# v
# addressed
# languid
# encouraging
# shyly
# i--i
# present--at
# sternly
# clearly
# sizes
# confusing
# isn't
# haven't
# turn
# chrysalis--you
# know--and
# butterfly
# may
# contemptuously
# brought
# irritated
# caterpillar's
# remarks
# state
# promising
# swallowing
# anger
# wait
# puffed
# unfolded
# used--and
# busy
# bee
# father
# man
# incessantly
# stand
# youth
# son
# feared
# injure
# brain
# perfectly
# none
# most
# uncommonly
# fat
# back-somersault
# pray
# sage
# grey
# limbs
# supple
# ointment--one
# shilling
# sell
# couple
# weak
# tougher
# suet
# bones
# beak
# argued
# wife
# muscular
# strength
# jaw
# lasted
# steady
# balanced
# eel
# nose
# awfully
# clever
# questions
# airs
# stuff
# timidly
# altered
# decidedly
# changing
# often
# contradicted
# losing
# content
# wretched
# rearing
# upright
# piteous
# patiently
# chose
# yawned
# crawled
# merely
# taller
# shorter
# thoughtfully
# difficult
# broke
# nibbled
# right-hand
# violent
# blow
# underneath
# closely
# swallow
# morsel
# lefthand
# head's
# free
# alarm
# immense
# length
# rise
# stalk
# green
# result
# follow
# shaking
# distant
# serpent
# succeeded
# curving
# graceful
# zigzag
# dive
# tops
# wandering
# hiss
# draw
# pigeon
# flown
# beating
# wings
# screamed
# indignantly
# repeated
# subdued
# sob
# roots
# banks
# hedges
# serpents
# pleasing
# puzzled
# hatching
# eggs
# look-out
# sleep
# weeks
# sorry
# you've
# annoyed
# taken
# highest
# tree
# raising
# needs
# wriggling
# sky
# a--i'm
# invent
# i--i'm
# doubtfully
# changes
# deepest
# contempt
# girls
# denying
# telling
# tasted
# egg
# truthful
# they're
# silent
# adding
# matters
# yours
# raw
# settled
# nest
# crouched
# entangled
# branches
# untwist
# pieces
# nibbling
# bringing
# beautiful
# garden--how
# whoever
# lives
# frighten
# wits
# righthand
# vi
# pig
# pepper
# footman
# livery
# considered
# otherwise
# judging
# fish
# rapped
# loudly
# knuckles
# footmen
# powdered
# crept
# fish-footman
# producing
# letter
# invitation
# queen
# frog-footman
# order
# curls
# laughed
# ground
# staring
# stupidly
# knocked
# reasons
# secondly
# inside
# extraordinary
# within--a
# constant
# howling
# sneezing
# dish
# kettle
# between
# instance
# knock
# uncivil
# remarked
# tomorrow
# skimming
# footman's
# grazed
# maybe
# louder
# told
# dreadful
# muttered
# argue
# drive
# crazy
# repeating
# remark
# variations
# days
# whistling
# desperately
# he's
# idiotic
# kitchen
# smoke
# stool
# nursing
# baby
# cook
# leaning
# stirring
# cauldron
# soup
# sneezed
# occasionally
# alternately
# moment's
# pause
# sneeze
# hearth
# grinning
# ear
# manners
# grins
# cheshire
# violence
# courage
# grinned
# pleased
# introduce
# fix
# throwing
# within
# baby--the
# fire-irons
# saucepans
# plates
# dishes
# already
# blows
# jumping
# agony
# terror
# precious
# unusually
# saucepan
# flew
# carried
# minded
# growl
# faster
# advantage
# takes
# twenty-four
# hours
# axis
# axes
# chop
# glanced
# meant
# hint
# busily
# bother
# abide
# figures
# singing
# lullaby
# shake
# line
# roughly
# boy
# beat
# sneezes
# annoy
# teases
# ):
# wow
# sang
# verse
# song
# tossing
# howled
# thoroughly
# enjoy
# pleases
# flinging
# threw
# frying-pan
# missed
# caught
# queer-shaped
# creature
# star-fish
# snorting
# steam-engine
# doubling
# straightening
# proper
# twist
# tight
# prevent
# undoing
# kill
# murder
# grunted
# grunt
# expressing
# turn-up
# snout
# also
# extremely
# sobbing
# seriously
# sobbed
# neither
# less
# carry
# relieved
# trot
# dreadfully
# ugly
# handsome
# pigs
# startled
# seeing
# bough
# yards
# good-natured
# teeth
# treated
# respect
# puss
# wider
# depends
# explanation
# denied
# waving
# hatter
# march
# hare
# visit
# mad
# we're
# dog's
# grant
# growls
# wags
# wag
# therefore
# growling
# invited
# happening
# by-the-bye
# became
# appear
# hatters
# raving
# mad--at
# branch
# fig
# appearing
# vanishing
# giddy
# ending
# farther
# chimneys
# shaped
# thatched
# raised
# towards
# instead
# vii
# tea-party
# front
# tea
# dormouse
# fast
# asleep
# using
# cushion
# resting
# elbows
# arm-chair
# wine
# civil
# laid
# wants
# cutting
# personal
# severity
# rude
# wide
# raven
# writing-desk
# fun
# they've
# riddles
# least--at
# say--that's
# breathe
# ravens
# writing-desks
# break
# month
# uneasily
# fourth
# butter
# works
# meekly
# crumbs
# grumbled
# bread-knife
# gloomily
# cup
# shoulder
# tells
# o'clock
# year
# readily
# stays
# hatter's
# poured
# riddle
# slightest
# wearily
# waste
# answers
# cautiously
# music
# accounts
# terms
# he'd
# clock
# twinkling
# half-past
# then--i
# mournfully
# quarrelled
# march--just
# spoon
# concert
# given
# hearts
# sing
# twinkle
# fly
# tea-tray
# pinch
# bawled
# murdering
# exclaimed
# mournful
# tea-things
# sigh
# we've
# wash
# whiles
# interrupted
# yawning
# vote
# lady
# alarmed
# proposal
# wake
# pinched
# fellows
# sisters
# names
# elsie
# lacie
# tillie
# lived
# bottom
# interest
# eating
# drinking
# treacle
# ill
# ways
# living
# opinion
# who's
# triumphantly
# helped
# bread-and-butter
# treacle-well
# sh
# sulkily
# interrupt
# consented
# sisters--they
# learning
# promise
# clean
# dormouse's
# unwillingly
# upset
# milk-jug
# offend
# water-well
# treacle-well--eh
# choosing
# interrupting
# rubbing
# manner
# things--everything
# begins
# m
# closed
# doze
# woke
# mouse-traps
# moon
# memory
# muchness--you
# muchness
# drawing
# piece
# rudeness
# disgust
# teapot
# stupidest
# leading
# everything's
# today
# unlocking
# then--she
# flower-beds
# viii
# queen's
# croquet-ground
# rose-tree
# entrance
# roses
# gardeners
# painting
# red
# paint
# jogged
# blame
# deserved
# beheaded
# spoken
# him--it
# tulip-roots
# onions
# flung
# brush
# unjust
# chanced
# watching
# checked
# afore
# themselves
# flat
# faces
# eager
# soldiers
# carrying
# clubs
# oblong
# corners
# courtiers
# ornamented
# diamonds
# royal
# merrily
# couples
# guests
# mostly
# kings
# queens
# recognised
# noticing
# knave
# king's
# crimson
# velvet
# procession
# king
# doubtful
# lie
# rule
# processions
# opposite
# smiled
# idiot
# majesty
# pack
# cards
# needn't
# rosetree
# pattern
# backs
# glaring
# beast
# consider
# bowing
# humble
# knee
# meanwhile
# examining
# remaining
# execute
# unfortunate
# protection
# flower-pot
# marched
# evidently
# roared
# it's--it's
# fine
# peeping
# hush
# whispered
# execution
# boxed
# scream
# laughter
# places
# thunder
# ridges
# furrows
# balls
# hedgehogs
# mallets
# flamingoes
# double
# arches
# chief
# managing
# flamingo
# body
# tucked
# comfortably
# straightened
# hedgehog
# expression
# bursting
# laughing
# provoking
# unrolled
# act
# crawling
# ridge
# furrow
# send
# doubled-up
# parts
# players
# played
# turns
# quarrelling
# fighting
# furious
# stamping
# shouting
# uneasy
# dispute
# beheading
# alive
# appearance
# nodded
# account
# someone
# fairly
# complaining
# quarrel
# oneself
# speak--and
# attends
# arch
# ground--and
# croqueted
# win
# finishing
# cat's
# friend
# mine--a
# kiss
# likes
# impertinent
# removed
# passing
# settling
# difficulties
# executioner
# screaming
# search
# engaged
# fight
# croqueting
# helpless
# collected
# appealed
# settle
# arguments
# executioner's
# unless
# weren't
# anxious
# prison
# arrow
# fading
# entirely
# disappeared
# wildly
# ix
# mock
# turtle's
# affectionately
# pleasant
# hopeful
# without--maybe
# hot-tempered
# vinegar
# sour--and
# camomile
# bitter--and--and
# barley-sugar
# sweet-tempered
# stingy
# forget
# moral
# hasn't
# tut
# squeezed
# closer
# keeping
# uncomfortably
# bore
# game's
# tis
# minding
# morals
# waist
# experiment
# bite
# mustard
# feather
# flock
# mineral
# agree
# mustard-mine
# attended
# vegetable
# imagine
# present
# cheap
# birthday
# dig
# worried
# duchess's
# died
# favourite
# linked
# hers
# tremble
# thunderstorm
# fair
# warning
# choice
# absence
# shade
# delay
# cost
# whom
# sentenced
# custody
# turtle
# company
# pardoned
# executions
# gryphon
# sun
# picture
# lazy
# leaving
# rubbed
# watched
# chuckled
# executes
# ledge
# rock
# heart
# pitied
# sorrow
# hollow
# occasional
# exclamation
# hjckrrh
# heavy
# calmly
# school
# turtle--we
# tortoise
# sink
# mayn't
# educations--in
# day-school
# proud
# extras
# learned
# relief
# ours
# washing--extra
# afford
# regular
# inquired
# reeling
# writhing
# arithmetic--ambition
# distraction
# uglification
# derision
# lifted
# uglifying
# beautify
# means--to--make--anything--prettier
# uglify
# simpleton
# encouraged
# mystery
# counting
# subjects
# flappers
# ancient
# modern
# seaography
# drawling--the
# drawling-master
# conger-eel
# week
# drawling
# fainting
# coils
# stiff
# classics
# grief
# hid
# lessen
# eleventh
# holiday
# twelfth
# games
# x
# lobster
# quadrille
# flapper
# sobs
# bone
# punching
# recovered
# cheeks
# introduced
# delightful
# dance
# form
# sea-shore
# lines
# seals
# turtles
# salmon
# cleared
# jelly-fish
# advance
# partner
# partners
# lobsters
# retire
# bound
# somersault
# capering
# yelled
# land
# figure
# dropping
# pretty
# dancing
# treading
# toes
# forepaws
# mark
# whiting
# snail
# porpoise
# shingle--will
# join
# askance
# thanked
# kindly
# scaly
# england
# france
# beloved
# they--you've
# dinn
# tails
# mouths--and
# mouths
# thrown
# shiny
# blacking
# soles
# eels
# shrimp
# thoughts
# obliged
# anywhere
# journey
# purpose
# adventures--beginning
# impatient
# explanations
# gained
# listeners
# part
# sluggard
# baked
# sugar
# eyelids
# trims
# belt
# buttons
# editions
# follows
# sands
# gay
# lark
# contemptuous
# tones
# shark
# tide
# rises
# sharks
# around
# tremulous
# uncommon
# explained
# persisted
# disobey
# owl
# panther
# sharing
# pie
# pie-crust
# gravy
# meat
# share
# treat
# boon
# permitted
# received
# fork
# banquet
# hm
# accounting
# tastes
# rich
# tureen
# dainties
# evening
# beau--ootiful
# soo--oop
# e--e--evening
# cares
# pennyworth
# beauti--ful
# trial's
# panted
# faintly
# breeze
# xi
# stole
# tarts
# seated
# throne
# arrived
# them--all
# standing
# chains
# soldier
# guard
# trumpet
# scroll
# parchment
# court
# them--'i
# refreshments
# pass
# justice
# books
# wig
# wore
# frontispiece
# comfortable
# becoming
# jury-box
# jurors
# rightly
# jury-men
# writing
# slates
# indignant
# spectacles
# spell
# neighbour
# muddle
# slates'll
# pencil
# squeaked
# quickly
# juror
# slate
# herald
# accusation
# blew
# blasts
# summer
# verdict
# witness
# teacup
# sent
# arm-in-arm
# fourteenth
# fifteenth
# sixteenth
# wrote
# dates
# reduced
# shillings
# pence
# hat
# stolen
# memorandum
# fidgeted
# evidence
# spot
# encourage
# shifting
# remain
# squeeze
# boldly
# reasonable
# pace
# ridiculous
# fashion
# officers
# list
# singers
# tea--not
# so--and
# thin--and
# t
# dunce
# twinkled
# that--only
# deny
# denies
# miserable
# speaker
# suppressed
# canvas
# bag
# tied
# strings
# guinea-pig
# newspapers
# trials
# attempts
# applause
# understood
# lower
# officer
# pepper-box
# cross-examine
# folding
# collar
# shrieked
# behead
# suppress
# undertone
# ache
# fumbled
# xii
# flurry
# tipped
# skirt
# upsetting
# jurymen
# sprawling
# reminding
# globe
# goldfish
# accidentally
# dismay
# accident
# vague
# die
# cannot
# places--all
# emphasis
# haste
# downwards
# unable
# signifies
# shock
# pencils
# diligently
# overcome
# gazing
# unimportant
# respectful
# important--unimportant--unimportant--important
# note-book
# cackled
# forty-two
# persons
# mile
# invented
# oldest
# prisoner
# to--to
# directed
# verses
# prisoner's
# handwriting
# queerest
# imitated
# else's
# prove
# signed
# sign
# mischief
# honest
# clapping
# proves
# guilt
# character
# push
# returned
# involved
# affair
# trusts
# fit
# obstacle
# ourselves
# secret
# sixpence
# atom
# attempted
# saves
# spreading
# cardboard
# clearer
# fits
# furiously
# inkstand
# ink
# trickling
# pun
# twentieth
# first--verdict
# purple
# rose
# flying
# brushing
# fluttered
# kissed
# wonderful
# setting
# dreaming
# dreamed
# clasped
# hers--she
# toss
# eyes--and
# listened
# sister's
# rustled
# by--the
# splashed
# neighbouring
# pool--she
# rattle
# teacups
# shared
# never-ending
# meal
# execution--once
# pig-baby
# crashed
# it--once
# lizard's
# slate-pencil
# choking
# believed
# reality--the
# rustling
# rippling
# reeds--the
# tinkling
# sheep-bells
# cries
# shepherd
# boy--and
# noises
# clamour
# farm-yard--while
# lowing
# cattle
# lastly
# pictured
# after-time
# woman
# riper
# years
# loving
# childhood
# gather
# sorrows
# joys
# remembering
# child-life
# happy
# <UNK>

# %% [markdown]
# We can check if a word is included in the vocabulary or the counts of a word in the vocabulary

# %%
# Get the count of a word in the vocabulary
print(vocabulary_train['alice'])
print(vocabulary_train['car'])

# Check if a word is in the vocabulary
print ('alice' in vocabulary_train)
print ('car' in vocabulary_train)


# Another way to check if a word is in the vocabulary
print (vocabulary_train.lookup('alice'))
print (vocabulary_train.lookup(['alice', 'car', 'the', 'computer']))
# Out:
# 386
# 0
# True
# False
# alice
# ('alice', '<UNK>', 'the', '<UNK>')

# %% [markdown]
# #### Train the model
#
# We can use different types of models corresponding to different ways of computing n-gram probabilities, by applying different smoothing techniques: basic MLE, Laplace, Backoff, ...
#
# See the complete documentation at https://www.nltk.org/api/nltk.lm.html

# %%
from nltk.lm.models import MLE, Laplace, StupidBackoff

# order of n-grams = 2
n = 2
lm_basic = MLE(n, vocabulary=vocabulary_train)
lm_laplace = Laplace(n, vocabulary=vocabulary_train)
lm_backoff = StupidBackoff(alpha = 0.4, order = n, vocabulary=vocabulary_train)

# Fit the models with the training n-grams
train, vocab = padded_everygram_pipeline(n, sentences_tokenized)
lm_basic.fit(train)
train, vocab = padded_everygram_pipeline(n, sentences_tokenized)
lm_laplace.fit(train)
train, vocab = padded_everygram_pipeline(n, sentences_tokenized)
lm_backoff.fit(train)

# %% [markdown]
# #### Evaluate the model
#
# We can get the probability given by the model to any n-gram (also the log of the probability to avoid numerical issues)

# %%
# Get the probability of the unigram 'alice'
print("MLE probability of 'alice': ", lm_basic.score('alice'), lm_basic.logscore('alice')) 
print("Laplace probability of 'alice': ", lm_laplace.score('alice'), lm_laplace.logscore('alice'))
print("StupidBackoff probability of 'alice': ", lm_backoff.score('alice'), lm_backoff.logscore('alice'))

# Get the probability of the bigram ('alice', 'was')
print("MLE probability of ('alice', 'was'): ", lm_basic.score('was', ['alice']), lm_basic.logscore('was', ['alice']))
print("Laplace probability of ('alice', 'was'): ", lm_laplace.score('was', ['alice']), lm_laplace.logscore('was', ['alice']))
print("StupidBackoff probability of ('alice', 'was'): ", lm_backoff.score('was', ['alice']), lm_backoff.logscore('was', ['alice']))
# Out:
# MLE probability of 'alice':  0.010460988102658608 -6.578837060610674
# Laplace probability of 'alice':  0.009754990925589837 -6.67964375386906
# StupidBackoff probability of 'alice':  0.010460988102658608 -6.578837060610674
# MLE probability of ('alice', 'was'):  0.04404145077720207 -4.5049941960177415
# Laplace probability of ('alice', 'was'):  0.005698005698005698 -7.45532722030456
# StupidBackoff probability of ('alice', 'was'):  0.04404145077720207 -4.5049941960177415

# %% [markdown]
# We can also evalute the quality of the model using perplexity

# %%
train, vocab = padded_everygram_pipeline(n, sentences_tokenized)
test = [n_gram for sentence in train for n_gram in sentence]
print("MLE perplexity of the train data: ", lm_basic.perplexity(test))
print("Laplace perplexity of the train data: ", lm_laplace.perplexity(test))
print("StupidBackoff perplexity of the train data: ", lm_backoff.perplexity(test))
# Out:
# MLE perplexity of the train data:  67.88670218144063
# Laplace perplexity of the train data:  281.5965005703454
# StupidBackoff perplexity of the train data:  67.88670218144063

# %% [markdown]
# <img src="./note.png" width = "40" height = "40" alt="note" align=top />
#
# 1. Try to change some parameters of the language model (order of n-grams, cutoff parameter, type of model, ...) and evaluate the impact of these variations using perplexity
# 2. Create a function to generate new text using the language model based on a previous context (sample always the most probable word based on the context)
# 3. What is the quality of the generated text? Is there any signifficant difference by changing the parameters of the language model?

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# We can quantitatively evaluate the quality of the generated text by comparing to a reference text using BLEU, ROUGE and METEOR, using the library `evaluate`: https://pypi.org/project/evaluate/

# %%
# %pip install evaluate
# %pip install rouge_score
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-4.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in c:\programdata\anaconda3\lib\site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in c:\programdata\anaconda3\lib\site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in c:\programdata\anaconda3\lib\site-packages (from evaluate) (4.66.5)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.19-py312-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\programdata\anaconda3\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Collecting huggingface-hub>=0.7.0 (from evaluate)
#   Downloading huggingface_hub-1.4.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.13.1)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\programdata\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (21.0.0)
# Requirement already satisfied: httpx<1.0.0 in c:\programdata\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (0.27.0)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.18-py312-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\programdata\anaconda3\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.10.5)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub>=0.7.0->evaluate)
#   Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: shellingham in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: typer-slim in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (0.20.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Collecting dill (from evaluate)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2026.1.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.11.0)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.0.2)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate) (0.14.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: click>=8.0.0 in c:\programdata\anaconda3\lib\site-packages (from typer-slim->huggingface-hub>=0.7.0->evaluate) (8.1.7)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
# Downloading datasets-4.5.0-py3-none-any.whl (515 kB)
# Downloading huggingface_hub-1.4.1-py3-none-any.whl (553 kB)
#    ---------------------------------------- 0.0/553.3 kB ? eta -:--:--
#    --------------------------------------- 553.3/553.3 kB 18.2 MB/s eta 0:00:00
# Downloading multiprocess-0.70.18-py312-none-any.whl (150 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl (31 kB)
# Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 42.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, hf-xet, dill, multiprocess, huggingface-hub, datasets, evaluate
# Successfully installed datasets-4.5.0 dill-0.4.0 evaluate-0.4.6 hf-xet-1.2.0 huggingface-hub-1.4.1 multiprocess-0.70.18 xxhash-3.6.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts hf.exe and tiny-agents.exe are installed in 'C:\Users\ernest\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script datasets-cli.exe is installed in 'C:\Users\ernest\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script evaluate-cli.exe is installed in 'C:\Users\ernest\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import evaluate
generated_sentence = "This is a generated sentence using the MLE model."
reference_sentence = "This is a new text using a language model"

bleu_metric = evaluate.load('bleu')
bleu1 = bleu_metric.compute(predictions=[generated_sentence], references=[reference_sentence], max_order=1)
bleu2 = bleu_metric.compute(predictions=[generated_sentence], references=[reference_sentence], max_order=2)
print("BLEU-1 score: ", bleu1['bleu'])
print("BLEU-2 score: ", bleu2['bleu'])

rouge_metric = evaluate.load('rouge')
rouge = rouge_metric.compute(predictions=[generated_sentence], references=[reference_sentence])
print(f"ROUGE-1 F1 Score: {rouge['rouge1']:.2f}")
print(f"ROUGE-L F1 Score: {rouge['rougeL']:.2f}")

meteor_metric = evaluate.load('meteor')
meteor = meteor_metric.compute(predictions=[generated_sentence], references=[reference_sentence])
print(f"METEOR Score: {meteor['meteor']:.2f}")
# Out:
# BLEU-1 score:  0.5
# BLEU-2 score:  0.3333333333333333
# ROUGE-1 F1 Score: 0.56
# ROUGE-L F1 Score: 0.56
# METEOR Score: 0.41
# [nltk_data] Downloading package wordnet to C:\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
